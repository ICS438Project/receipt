# %%
import pandas as pd

# %%
# List of clothing items and example vendors

clothing_items = [
    {"Item": "T-shirt", "Example Vendor": "H&M"},
    {"Item": "Jeans", "Example Vendor": "Levi's"},
    {"Item": "Sneakers", "Example Vendor": "Nike"},
    {"Item": "Dress", "Example Vendor": "Zara"},
    {"Item": "Suit", "Example Vendor": "Armani"},
    {"Item": "Socks", "Example Vendor": "Adidas"},
    {"Item": "Underwear", "Example Vendor": "Calvin Klein"},
    {"Item": "Jacket", "Example Vendor": "North Face"},
    {"Item": "Skirt", "Example Vendor": "Gucci"},
    {"Item": "Sweater", "Example Vendor": "Ralph Lauren"},
    {"Item": "Scarf", "Example Vendor": "Burberry"},
    {"Item": "Belt", "Example Vendor": "Hermes"},
    {"Item": "Gloves", "Example Vendor": "Coach"},
    {"Item": "Cap", "Example Vendor": "New Era"},
    {"Item": "Sunglasses", "Example Vendor": "Ray-Ban"},
    {"Item": "Watch", "Example Vendor": "Rolex"},
    {"Item": "Backpack", "Example Vendor": "JanSport"},
    {"Item": "Tie", "Example Vendor": "Brooks Brothers"},
    {"Item": "Swimsuit", "Example Vendor": "Speedo"},
    {"Item": "Sandals", "Example Vendor": "Birkenstock"},
    {"Item": "Hoodie", "Example Vendor": "Supreme"},
    {"Item": "Leggings", "Example Vendor": "Lululemon"},
    {"Item": "Blazer", "Example Vendor": "Hugo Boss"},
    {"Item": "Boots", "Example Vendor": "Timberland"},
    {"Item": "Cufflinks", "Example Vendor": "Tiffany & Co."},
    {"Item": "Pajamas", "Example Vendor": "Victoria's Secret"},
    {"Item": "Beanie", "Example Vendor": "Carhartt"},
    {"Item": "Tracksuit", "Example Vendor": "Puma"},
    {"Item": "Slippers", "Example Vendor": "Ugg"},
    {"Item": "Wallet", "Example Vendor": "Louis Vuitton"},
    {"Item": "Raincoat", "Example Vendor": "Patagonia"},
    {"Item": "Shawl", "Example Vendor": "Chanel"},
    {"Item": "Formal Shoes", "Example Vendor": "Clarks"},
    {"Item": "Bra", "Example Vendor": "Savage X Fenty"},
    {"Item": "Sports Jacket", "Example Vendor": "Columbia"},
    {"Item": "Yoga Pants", "Example Vendor": "Alo Yoga"},
    {"Item": "Flip Flops", "Example Vendor": "Havaianas"},
    {"Item": "Overcoat", "Example Vendor": "Burberry"},
    {"Item": "Briefcase", "Example Vendor": "Samsonite"},
    {"Item": "Ankle Boots", "Example Vendor": "Dr. Martens"},
    {"Item": "Sports Bra", "Example Vendor": "Under Armour"},
    {"Item": "Knee High Socks", "Example Vendor": "Happy Socks"},
    {"Item": "Trench Coat", "Example Vendor": "London Fog"},
    {"Item": "Running Shoes", "Example Vendor": "Asics"},
    {"Item": "Basketball Shorts", "Example Vendor": "Jordan"},
    {"Item": "Baseball Cap", "Example Vendor": "47 Brand"},
    {"Item": "Fleece Jacket", "Example Vendor": "Columbia"},
    {"Item": "Leather Belt", "Example Vendor": "Montblanc"},
    {"Item": "Evening Gown", "Example Vendor": "Oscar de la Renta"},
    {"Item": "Bow Tie", "Example Vendor": "Tom Ford"},
    {"Item": "Crossbody Bag", "Example Vendor": "Kate Spade"},
    {"Item": "Denim Jacket", "Example Vendor": "Wrangler"},
    {"Item": "Winter Coat", "Example Vendor": "Canada Goose"},
    {"Item": "Fisherman's Hat", "Example Vendor": "Stussy"},
    {"Item": "Wool Scarf", "Example Vendor": "Acne Studios"},
    {"Item": "Bomber Jacket", "Example Vendor": "Alpha Industries"},
    {"Item": "Cargo Pants", "Example Vendor": "Carhartt"},
    {"Item": "High Heels", "Example Vendor": "Jimmy Choo"},
    {"Item": "Sweatpants", "Example Vendor": "Champion"},
    {"Item": "Cardigan", "Example Vendor": "Banana Republic"},
    {"Item": "Knit Hat", "Example Vendor": "The North Face"},
    {"Item": "Lingerie", "Example Vendor": "Agent Provocateur"},
    {"Item": "Maternity Dress", "Example Vendor": "Motherhood Maternity"},
    {"Item": "Cargo Shorts", "Example Vendor": "Dockers"},
    {"Item": "Wristlet", "Example Vendor": "Coach"},
    {"Item": "Denim Shorts", "Example Vendor": "American Eagle"},
    {"Item": "Windbreaker", "Example Vendor": "Adidas"},
    {"Item": "Long Sleeve Shirt", "Example Vendor": "Uniqlo"},
    {"Item": "Ballet Flats", "Example Vendor": "Tory Burch"},
    {"Item": "Vest", "Example Vendor": "Patagonia"},
    {"Item": "Messenger Bag", "Example Vendor": "Fossil"},
    {"Item": "Sports Socks", "Example Vendor": "Nike"},
    {"Item": "Turtleneck", "Example Vendor": "J.Crew"},
    {"Item": "Mittens", "Example Vendor": "REI"},
    {"Item": "Cycling Shorts", "Example Vendor": "Pearl Izumi"},
    {"Item": "Hiking Boots", "Example Vendor": "Merrell"},
    {"Item": "Workout Tank", "Example Vendor": "Gymshark"},
    {"Item": "Leather Jacket", "Example Vendor": "Schott NYC"},
    {"Item": "Boxer Briefs", "Example Vendor": "Tommy Hilfiger"},
    {"Item": "Cami Top", "Example Vendor": "Forever 21"},
    {"Item": "Fedora", "Example Vendor": "Borsalino"},
    {"Item": "Leather Gloves", "Example Vendor": "Dents"},
    {"Item": "Board Shorts", "Example Vendor": "Quiksilver"},
    {"Item": "Plaid Shirt", "Example Vendor": "Abercrombie & Fitch"},
    {"Item": "Wool Coat", "Example Vendor": "J.Crew"},
    {"Item": "Cropped Top", "Example Vendor": "Topshop"},
    {"Item": "Yoga Shorts", "Example Vendor": "PrAna"},
    {"Item": "Straw Hat", "Example Vendor": "Tommy Bahama"},
    {"Item": "Riding Boots", "Example Vendor": "Ariat"},
    {"Item": "Sports Hoodie", "Example Vendor": "Reebok"},
    {"Item": "Compression Leggings", "Example Vendor": "2XU"},
    {"Item": "Bikini", "Example Vendor": "Triangl"},
    {"Item": "Chelsea Boots", "Example Vendor": "Blundstone"},
    {"Item": "Aviator Sunglasses", "Example Vendor": "Persol"},
    {"Item": "Brogues", "Example Vendor": "Allen Edmonds"},
    {"Item": "Varsity Jacket", "Example Vendor": "Starter"},
    {"Item": "Athletic Shorts", "Example Vendor": "Adidas"},
    {"Item": "Wool Sweater", "Example Vendor": "Woolrich"},
    {"Item": "Lace Dress", "Example Vendor": "Self-Portrait"},
    {"Item": "Fitness Tracker", "Example Vendor": "Fitbit"},
    {"Item": "Beanie", "Example Vendor": "Patagonia"},
    {"Item": "Corduroy Pants", "Example Vendor": "Levi's"},
    {"Item": "Snow Boots", "Example Vendor": "Sorel"},
    {"Item": "Running Tights", "Example Vendor": "New Balance"},
    {"Item": "Maxi Dress", "Example Vendor": "Free People"},
    {"Item": "Graphic Tee", "Example Vendor": "Vans"},
    {"Item": "Polo Shirt", "Example Vendor": "Lacoste"},
    {"Item": "Silk Scarf", "Example Vendor": "Hermes"},
    {"Item": "Mini Skirt", "Example Vendor": "Missguided"},
    {"Item": "Espadrilles", "Example Vendor": "Castaner"},
    {"Item": "Parka", "Example Vendor": "Fjallraven"},
    {"Item": "Jumpsuit", "Example Vendor": "ASOS"},
    {"Item": "Duffle Bag", "Example Vendor": "The North Face"},
    {"Item": "Bucket Hat", "Example Vendor": "Kangol"},
    {"Item": "Bodycon Dress", "Example Vendor": "Fashion Nova"},
    {"Item": "Peacoat", "Example Vendor": "Schott NYC"},
    {"Item": "Loafers", "Example Vendor": "G.H. Bass & Co."},
    {"Item": "Lace Bralette", "Example Vendor": "Aerie"},
    {"Item": "Flannel Shirt", "Example Vendor": "LL Bean"},
    {"Item": "Cargo Jacket", "Example Vendor": "Levi's"},
    {"Item": "Work Boots", "Example Vendor": "Red Wing Shoes"},
    {"Item": "Leather Wallet", "Example Vendor": "Fossil"},
    {"Item": "Chinos", "Example Vendor": "Dockers"},
    {"Item": "Cycling Jersey", "Example Vendor": "Castelli"},
    {"Item": "Puffer Jacket", "Example Vendor": "Moncler"},
    {"Item": "Dress Shoes", "Example Vendor": "Johnston & Murphy"},
    {"Item": "Thermal Shirt", "Example Vendor": "Under Armour"},
    {"Item": "Shift Dress", "Example Vendor": "Ann Taylor"},
    {"Item": "Waistcoat", "Example Vendor": "Brooks Brothers"},
    {"Item": "Yoga Mat Bag", "Example Vendor": "Manduka"},
    {"Item": "Basketball Shoes", "Example Vendor": "Adidas"},
    {"Item": "Down Vest", "Example Vendor": "The North Face"},
    {"Item": "Running Cap", "Example Vendor": "Nike"},
    {"Item": "Sarong", "Example Vendor": "Seafolly"},
    {"Item": "Combat Boots", "Example Vendor": "Dr. Martens"},
    {"Item": "Sweatshirt", "Example Vendor": "Champion"},
    {"Item": "Running Socks", "Example Vendor": "Balega"},
    {"Item": "Strappy Heels", "Example Vendor": "Steve Madden"},
    {"Item": "Denim Skirt", "Example Vendor": "Levi's"},
    {"Item": "Tennis Skirt", "Example Vendor": "Nike"},
    {"Item": "Fleece Vest", "Example Vendor": "Patagonia"},
    {"Item": "Biker Shorts", "Example Vendor": "Alo Yoga"},
    {"Item": "Tote Bag", "Example Vendor": "Michael Kors"},
    {"Item": "Overalls", "Example Vendor": "Dickies"},
    {"Item": "Harem Pants", "Example Vendor": "Free People"},
    {"Item": "Quarter-Zip Pullover", "Example Vendor": "The North Face"},
    {"Item": "Trucker Hat", "Example Vendor": "Von Dutch"},
    {"Item": "Shearling Jacket", "Example Vendor": "Acne Studios"},
    {"Item": "Hiking Pants", "Example Vendor": "Columbia"},
    {"Item": "Rash Guard", "Example Vendor": "O'Neill"},
    {"Item": "Gym Bag", "Example Vendor": "Adidas"},
    {"Item": "Kimono", "Example Vendor": "Anthropologie"},
    {"Item": "Wedge Sandals", "Example Vendor": "Clarks"},
    {"Item": "Wool Trousers", "Example Vendor": "Theory"},
    {"Item": "Leather Backpack", "Example Vendor": "Tumi"},
    {"Item": "Sweat Shorts", "Example Vendor": "Nike"},
    {"Item": "Rain Boots", "Example Vendor": "Hunter"},
    {"Item": "Poncho", "Example Vendor": "Pendleton"},
    {"Item": "Cross Trainers", "Example Vendor": "Reebok"},
    {"Item": "Base Layer", "Example Vendor": "Smartwool"},
    {"Item": "Velvet Blazer", "Example Vendor": "Ted Baker"},
    {"Item": "Camo Pants", "Example Vendor": "Rothco"},
    {"Item": "Linen Shirt", "Example Vendor": "Tommy Bahama"},
    {"Item": "Graphic Sweatshirt", "Example Vendor": "Stussy"},
    {"Item": "Cycling Shoes", "Example Vendor": "Shimano"},
    {"Item": "Silk Tie", "Example Vendor": "Dolce & Gabbana"},
    {"Item": "Surf Shorts", "Example Vendor": "Billabong"}
]

# %%
# Creating a DataFrame
df_clothing = pd.DataFrame(clothing_items)
df_clothing['Items'] = df_clothing['Item'] + " " + df_clothing['Example Vendor']
df_clothing = df_clothing.drop({'Item', 'Example Vendor'}, axis=1)
df_clothing
# Out:
#                          Items
# 0                  T-shirt H&M
# 1                 Jeans Levi's
# 2                Sneakers Nike
# 3                   Dress Zara
# 4                  Suit Armani
# ..                         ...
# 162   Linen Shirt Tommy Bahama
# 163  Graphic Sweatshirt Stussy
# 164      Cycling Shoes Shimano
# 165   Silk Tie Dolce & Gabbana
# 166      Surf Shorts Billabong
#
# [167 rows x 1 columns]

# %%
df_clothing.to_csv('clothing_datebase.csv', index=0)

# %% [markdown]
# ----

# %%
food_service_items = [
    {"Item": "Pizza", "Example Vendor": "Domino's Pizza"},
    {"Item": "Burger", "Example Vendor": "McDonald's"},
    {"Item": "Sushi", "Example Vendor": "Sushi Tei"},
    {"Item": "Pasta", "Example Vendor": "Olive Garden"},
    {"Item": "Coffee", "Example Vendor": "Starbucks"},
    {"Item": "Ice Cream", "Example Vendor": "Baskin-Robbins"},
    {"Item": "Sandwich", "Example Vendor": "Subway"},
    {"Item": "Steak", "Example Vendor": "Outback Steakhouse"},
    {"Item": "Salad", "Example Vendor": "Sweetgreen"},
    {"Item": "Tacos", "Example Vendor": "Taco Bell"},
    {"Item": "Chinese Food", "Example Vendor": "P.F. Chang's"},
    {"Item": "Donuts", "Example Vendor": "Dunkin' Donuts"},
    {"Item": "Chicken Wings", "Example Vendor": "Buffalo Wild Wings"},
    {"Item": "Smoothies", "Example Vendor": "Jamba Juice"},
    {"Item": "Bagels", "Example Vendor": "Einstein Bros. Bagels"},
    {"Item": "BBQ Ribs", "Example Vendor": "Famous Dave's"},
    {"Item": "Indian Food", "Example Vendor": "Tandoori Oven"},
    {"Item": "Falafel", "Example Vendor": "Halal Guys"},
    {"Item": "Thai Food", "Example Vendor": "Noodles & Company"},
    {"Item": "Fish and Chips", "Example Vendor": "Long John Silver's"},
    {"Item": "Paella", "Example Vendor": "La Tasca"},
    {"Item": "Korean BBQ", "Example Vendor": "Kang Hodong Baekjeong"},
    {"Item": "Gyros", "Example Vendor": "Daphne's"},
    {"Item": "Poutine", "Example Vendor": "Smoke's Poutinerie"},
    {"Item": "Vegetarian Food", "Example Vendor": "Vegetarian House"},
    {"Item": "Ramen", "Example Vendor": "Ippudo"},
    {"Item": "French Fries", "Example Vendor": "Five Guys"},
    {"Item": "Cheesecake", "Example Vendor": "The Cheesecake Factory"},
    {"Item": "Burritos", "Example Vendor": "Chipotle Mexican Grill"},
    {"Item": "Fried Chicken", "Example Vendor": "KFC"},
    {"Item": "Tapas", "Example Vendor": "Jaleo"},
    {"Item": "Vegan Food", "Example Vendor": "Veggie Grill"},
    {"Item": "Crepes", "Example Vendor": "Crepevine"},
    {"Item": "Dim Sum", "Example Vendor": "Yank Sing"},
    {"Item": "Shawarma", "Example Vendor": "Shawarma King"},
    {"Item": "Pho", "Example Vendor": "Pho 24"},
    {"Item": "Milkshakes", "Example Vendor": "Steak 'n Shake"},
    {"Item": "Soul Food", "Example Vendor": "Sylvia's Restaurant"},
    {"Item": "Cupcakes", "Example Vendor": "Sprinkles Cupcakes"},
    {"Item": "Mexican Food", "Example Vendor": "El Pollo Loco"},
    {"Item": "Greek Food", "Example Vendor": "The Greek Spot"},
    {"Item": "Hot Dogs", "Example Vendor": "Nathan's Famous"},
    {"Item": "Waffles", "Example Vendor": "Waffle House"},
    {"Item": "Lobster", "Example Vendor": "Red Lobster"},
    {"Item": "Gourmet Burgers", "Example Vendor": "Shake Shack"},
    {"Item": "Japanese Food", "Example Vendor": "Benihana"},
    {"Item": "Tiramisu", "Example Vendor": "Carrabba's Italian Grill"},
    {"Item": "Poke Bowls", "Example Vendor": "Poke Bar"},
    {"Item": "Catering Services", "Example Vendor": "Panera Bread"},
    {"Item": "Seafood", "Example Vendor": "Joe's Crab Shack"},
    {"Item": "Middle Eastern Food", "Example Vendor": "Mamoun's Falafel"},
    {"Item": "Brunch", "Example Vendor": "Brunch Café"},
    {"Item": "Gelato", "Example Vendor": "Gelato Fiasco"},
    {"Item": "Quesadillas", "Example Vendor": "Qdoba Mexican Eats"},
     {"Item": "Quesadillas", "Example Vendor": "Qdoba Mexican Eats"},
    {"Item": "Craft Beer", "Example Vendor": "The Craft Beer Co."},
    {"Item": "Macarons", "Example Vendor": "Ladurée"},
    {"Item": "Artisanal Bread", "Example Vendor": "Panera Bread"},
    {"Item": "Chocolate", "Example Vendor": "Ghirardelli"},
    {"Item": "Gourmet Cheese", "Example Vendor": "Murray's Cheese"},
    {"Item": "Organic Produce", "Example Vendor": "Whole Foods Market"},
    {"Item": "Sourdough Bread", "Example Vendor": "Boudin Bakery"},
    {"Item": "Tea", "Example Vendor": "Teavana"},
    {"Item": "Croissants", "Example Vendor": "Paul Bakery"},
    {"Item": "Wine", "Example Vendor": "Total Wine & More"},
    {"Item": "Craft Cocktails", "Example Vendor": "Death & Co"},
    {"Item": "Caviar", "Example Vendor": "Petrossian"},
    {"Item": "Gourmet Coffee", "Example Vendor": "Blue Bottle Coffee"},
    {"Item": "Charcuterie", "Example Vendor": "Di Bruno Bros"},
    {"Item": "Organic Meat", "Example Vendor": "The Butcher's Market"},
    {"Item": "Vegan Desserts", "Example Vendor": "Vegan Treats Bakery"},
    {"Item": "Gluten-Free Food", "Example Vendor": "The Gluten Free Bakery"},
    {"Item": "Gourmet Pizza", "Example Vendor": "Blaze Pizza"},
    {"Item": "Craft Soda", "Example Vendor": "Jones Soda Co."},
    {"Item": "Oysters", "Example Vendor": "Hog Island Oyster Co."},
    {"Item": "Truffle Oil", "Example Vendor": "Gourmet Food Store"},
    {"Item": "Gourmet Chocolate", "Example Vendor": "Godiva"},
    {"Item": "Specialty Tea", "Example Vendor": "Harney & Sons"},
    {"Item": "Organic Juice", "Example Vendor": "Pressed Juicery"},
    {"Item": "Pastry", "Example Vendor": "Patisserie Valerie"},
    {"Item": "Gourmet Ice Cream", "Example Vendor": "Salt & Straw"},
    {"Item": "Deli Sandwich", "Example Vendor": "Jersey Mike's Subs"},
    {"Item": "Ethiopian Food", "Example Vendor": "Ras Dashen"},
    {"Item": "Gourmet Burger", "Example Vendor": "In-N-Out Burger"},
    {"Item": "Baguette", "Example Vendor": "La Boulangerie"},
    {"Item": "Fine Dining", "Example Vendor": "The French Laundry"},
    {"Item": "BBQ Chicken", "Example Vendor": "El Pollo Loco"},
    {"Item": "Gourmet Salad", "Example Vendor": "Chopt Creative Salad Co."},
    {"Item": "Taproom", "Example Vendor": "The Taproom"},
    {"Item": "Sourdough Pizza", "Example Vendor": "Sourdough Pizza Co."},
    {"Item": "Tofu Dishes", "Example Vendor": "Tofu House"},
    {"Item": "Gourmet Donuts", "Example Vendor": "Doughnut Plant"},
    {"Item": "Artisanal Gelato", "Example Vendor": "Grom"},
    {"Item": "Gourmet Tacos", "Example Vendor": "Guerrilla Tacos"},
    {"Item": "French Cuisine", "Example Vendor": "Bistro Jeanty"},
    {"Item": "Craft Distillery", "Example Vendor": "High West Distillery"},
    {"Item": "Sustainable Seafood", "Example Vendor": "Bamboo Sushi"},
    {"Item": "Artisanal Coffee", "Example Vendor": "Stumptown Coffee Roasters"},
    {"Item": "Gourmet Cupcakes", "Example Vendor": "Georgetown Cupcake"},
    {"Item": "Wine Bar", "Example Vendor": "The Tasting Room"},
    {"Item": "Gourmet Chocolate Cake", "Example Vendor": "Milk Bar"},
    {"Item": "Farm-to-Table Dining", "Example Vendor": "Farmhouse Inn"},
    {"Item": "Vegan Pizza", "Example Vendor": "Double Zero"},
    {"Item": "French Pastries", "Example Vendor": "Maison Kayser"},
    {"Item": "Gourmet Cheeseburger", "Example Vendor": "The Counter"},
    {"Item": "Craft Brewery", "Example Vendor": "Stone Brewing"},
    {"Item": "Vietnamese Cuisine", "Example Vendor": "Pho Hoa"},
    {"Item": "Italian Ice", "Example Vendor": "Rita's Italian Ice"},
    {"Item": "Farmers Market", "Example Vendor": "Union Square Greenmarket"},
    {"Item": "Dumplings", "Example Vendor": "Din Tai Fung"},
    {"Item": "Organic Salad", "Example Vendor": "Sweetgreen"},
    {"Item": "Gourmet Sandwich", "Example Vendor": "Earl of Sandwich"},
    {"Item": "Spanish Cuisine", "Example Vendor": "Barcelona Wine Bar"},
    {"Item": "Gourmet Hot Dogs", "Example Vendor": "Portillo's"},
    {"Item": "Gourmet Sausage", "Example Vendor": "The Sausage Factory"},
    {"Item": "Bakery Cafe", "Example Vendor": "Corner Bakery Cafe"},
    {"Item": "Craft Beer Pub", "Example Vendor": "The Alchemist"},
    {"Item": "Gourmet Steak", "Example Vendor": "Ruth's Chris Steak House"},
    {"Item": "Artisanal Chocolate", "Example Vendor": "Jacques Torres Chocolate"},
    {"Item": "Gourmet Pasta", "Example Vendor": "Eataly"},
    {"Item": "Kombucha", "Example Vendor": "GT's Kombucha"},
    {"Item": "Specialty Coffee", "Example Vendor": "Intelligentsia Coffee"},
    {"Item": "Turkish Cuisine", "Example Vendor": "Saray Restaurant"},
    {"Item": "Gourmet Bagels", "Example Vendor": "Ess-a-Bagel"},
    {"Item": "Microbrewery", "Example Vendor": "Brooklyn Brewery"},
    {"Item": "Gourmet Pies", "Example Vendor": "Pie Sisters"},
    {"Item": "Sushi Bar", "Example Vendor": "Sushi Nakazawa"},
    {"Item": "Brazilian Steakhouse", "Example Vendor": "Fogo de Chão"},
    {"Item": "Russian Cuisine", "Example Vendor": "Mari Vanna"},
    {"Item": "Gourmet Pizza Bar", "Example Vendor": "Robertas"},
    {"Item": "Gourmet Burger Joint", "Example Vendor": "BurgerFi"},
    {"Item": "Artisanal Bakery", "Example Vendor": "Tartine Bakery"},
    {"Item": "Craft Soda Bar", "Example Vendor": "Galco's Soda Pop Stop"},
    {"Item": "Gourmet Bistro", "Example Vendor": "Buvette"},
    {"Item": "Polish Cuisine", "Example Vendor": "Pierogi Mountain"},
    {"Item": "Craft Cocktail Bar", "Example Vendor": "The Aviary"},
    {"Item": "Sushi Train", "Example Vendor": "Genki Sushi"},
    {"Item": "Organic Coffee Shop", "Example Vendor": "Counter Culture Coffee"},
    {"Item": "Vegan Bistro", "Example Vendor": "Plant Food + Wine"},
    {"Item": "Gourmet Bakery", "Example Vendor": "Dominique Ansel Bakery"},
    {"Item": "Italian Deli", "Example Vendor": "Di Bruno Bros"},
    {"Item": "Craft Wine Bar", "Example Vendor": "City Winery"},
    {"Item": "Gourmet Gelateria", "Example Vendor": "Gelato & Co."},
    {"Item": "Argentinian Grill", "Example Vendor": "Gaucho Grill"},
    {"Item": "Specialty Cake Shop", "Example Vendor": "Carlos Bakery"},
    {"Item": "Organic Vegan Cafe", "Example Vendor": "Café Gratitude"},
    {"Item": "Artisanal Pizzeria", "Example Vendor": "Lucali"},
    {"Item": "Craft Cheese Shop", "Example Vendor": "Cheese Board Pizza"},
    {"Item": "Gourmet Cookie Shop", "Example Vendor": "Levain Bakery"},
    {"Item": "Specialty Tea House", "Example Vendor": "Samovar Tea Lounge"},
    {"Item": "Winery", "Example Vendor": "Robert Mondavi Winery"},
    {"Item": "Organic Bakery", "Example Vendor": "Amy's Bread"},
    {"Item": "Fine Wine Store", "Example Vendor": "Astor Wines & Spirits"}
]

# %%
# Creating a DataFrame
df_food_service = pd.DataFrame(food_service_items)
df_food_service['Items'] = df_food_service['Item'] + " " + df_food_service['Example Vendor']
df_food_service = df_food_service.drop({'Item', 'Example Vendor'}, axis=1)
df_food_service
# Out:
#                                       Items
# 0                      Pizza Domino's Pizza
# 1                         Burger McDonald's
# 2                           Sushi Sushi Tei
# 3                        Pasta Olive Garden
# 4                          Coffee Starbucks
# ..                                      ...
# 148       Gourmet Cookie Shop Levain Bakery
# 149  Specialty Tea House Samovar Tea Lounge
# 150            Winery Robert Mondavi Winery
# 151              Organic Bakery Amy's Bread
# 152   Fine Wine Store Astor Wines & Spirits
#
# [153 rows x 1 columns]

# %%
df_food_service.to_csv('food_service_datebase.csv', index=0)

# %% [markdown]
# ---

# %%
# List of health and beauty items and example vendors
health_beauty_items = [
    {"Item": "Shampoo", "Example Vendor": "Pantene"},
    {"Item": "Conditioner", "Example Vendor": "Herbal Essences"},
    {"Item": "Toothpaste", "Example Vendor": "Colgate"},
    {"Item": "Body Wash", "Example Vendor": "Dove"},
    {"Item": "Moisturizer", "Example Vendor": "Cetaphil"},
    {"Item": "Deodorant", "Example Vendor": "Degree"},
    {"Item": "Face Wash", "Example Vendor": "Neutrogena"},
    {"Item": "Sunscreen", "Example Vendor": "Banana Boat"},
    {"Item": "Lip Balm", "Example Vendor": "Burt's Bees"},
    {"Item": "Makeup Remover", "Example Vendor": "Garnier"},
    {"Item": "Hand Cream", "Example Vendor": "L'Occitane"},
    {"Item": "Nail Polish", "Example Vendor": "OPI"},
    {"Item": "Hair Spray", "Example Vendor": "L'Oreal"},
    {"Item": "Foundation", "Example Vendor": "Maybelline"},
    {"Item": "Concealer", "Example Vendor": "Tarte"},
    {"Item": "Mascara", "Example Vendor": "Covergirl"},
    {"Item": "Eyeliner", "Example Vendor": "Stila"},
    {"Item": "Eye Shadow", "Example Vendor": "Urban Decay"},
    {"Item": "Lipstick", "Example Vendor": "MAC"},
    {"Item": "Blush", "Example Vendor": "NARS"},
    {"Item": "Eyebrow Pencil", "Example Vendor": "Anastasia Beverly Hills"},
    {"Item": "Face Serum", "Example Vendor": "The Ordinary"},
    {"Item": "Body Lotion", "Example Vendor": "Aveeno"},
    {"Item": "Hair Oil", "Example Vendor": "Moroccanoil"},
    {"Item": "Acne Treatment", "Example Vendor": "Proactiv"},
    {"Item": "Anti-Aging Cream", "Example Vendor": "Olay"},
    {"Item": "Face Mask", "Example Vendor": "Glamglow"},
    {"Item": "BB Cream", "Example Vendor": "Missha"},
    {"Item": "CC Cream", "Example Vendor": "IT Cosmetics"},
    {"Item": "Hair Dye", "Example Vendor": "Schwarzkopf"},
    {"Item": "Electric Toothbrush", "Example Vendor": "Oral-B"},
    {"Item": "Razor", "Example Vendor": "Gillette"},
    {"Item": "Shaving Cream", "Example Vendor": "Barbasol"},
    {"Item": "Perfume", "Example Vendor": "Chanel"},
    {"Item": "Cologne", "Example Vendor": "Dior"},
    {"Item": "Bath Bomb", "Example Vendor": "Lush"},
    {"Item": "Aftershave", "Example Vendor": "Nivea"},
    {"Item": "Hair Gel", "Example Vendor": "American Crew"},
    {"Item": "Dry Shampoo", "Example Vendor": "Batiste"},
    {"Item": "Cleansing Oil", "Example Vendor": "DHC"},
    {"Item": "Face Scrub", "Example Vendor": "St. Ives"},
    {"Item": "Hand Soap", "Example Vendor": "Method"},
    {"Item": "Foot Cream", "Example Vendor": "Eucerin"},
    {"Item": "Beard Oil", "Example Vendor": "Jack Black"},
    {"Item": "Eye Cream", "Example Vendor": "Kiehl's"},
    {"Item": "Nail Remover", "Example Vendor": "Sally Hansen"},
    {"Item": "Hair Wax", "Example Vendor": "TIGI"},
    {"Item": "Setting Spray", "Example Vendor": "Urban Decay"},
    {"Item": "Toner", "Example Vendor": "Thayers"},
    {"Item": "Exfoliating Pad", "Example Vendor": "Neogen"},
    {"Item": "Lip Gloss", "Example Vendor": "Fenty Beauty"},
    {"Item": "Highlighter", "Example Vendor": "BECCA"},
    {"Item": "Contour Kit", "Example Vendor": "Kat Von D"},
    {"Item": "Bronzer", "Example Vendor": "Benefit"},
    {"Item": "False Eyelashes", "Example Vendor": "Ardell"},
    {"Item": "Nail Clippers", "Example Vendor": "Tweezerman"},
    {"Item": "Hairbrush", "Example Vendor": "Wet Brush"},
    {"Item": "Makeup Brushes", "Example Vendor": "Sigma Beauty"},
    {"Item": "Face Primer", "Example Vendor": "Smashbox"},
    {"Item": "Lip Liner", "Example Vendor": "Charlotte Tilbury"},
    {"Item": "Bath Salts", "Example Vendor": "Dr Teal's"},
    {"Item": "Face Peel", "Example Vendor": "Drunk Elephant"},
    {"Item": "Hair Serum", "Example Vendor": "John Frieda"},
    {"Item": "Nail Strengthener", "Example Vendor": "OPI"},
    {"Item": "Hair Mask", "Example Vendor": "Olaplex"},
    {"Item": "Bubble Bath", "Example Vendor": "Philosophy"},
    {"Item": "Shower Gel", "Example Vendor": "The Body Shop"},
    {"Item": "Facial Cleanser", "Example Vendor": "CeraVe"},
    {"Item": "Body Scrub", "Example Vendor": "Frank Body"},
    {"Item": "Eyebrow Gel", "Example Vendor": "Glossier"},
    {"Item": "Shaving Balm", "Example Vendor": "The Art of Shaving"},
    {"Item": "Nail Cuticle Oil", "Example Vendor": "CND"},
    {"Item": "Lip Mask", "Example Vendor": "Laneige"},
    {"Item": "Hair Mousse", "Example Vendor": "Paul Mitchell"},
    {"Item": "Scalp Treatment", "Example Vendor": "Head & Shoulders"},
    {"Item": "Essential Oils", "Example Vendor": "doTERRA"},
    {"Item": "Body Oil", "Example Vendor": "Bio-Oil"},
    {"Item": "Facial Moisturizer", "Example Vendor": "La Roche-Posay"},
    {"Item": "Makeup Sponge", "Example Vendor": "Beautyblender"},
    {"Item": "Teeth Whitening Kit", "Example Vendor": "Crest"},
    {"Item": "Body Butter", "Example Vendor": "SheaMoisture"},
    {"Item": "Face Powder", "Example Vendor": "Laura Mercier"},
    {"Item": "Acne Patches", "Example Vendor": "COSRX"},
    {"Item": "Lash Serum", "Example Vendor": "L'Oreal"},
    {"Item": "Nail File", "Example Vendor": "Revlon"},
    {"Item": "Hair Clippers", "Example Vendor": "Wahl"},
    {"Item": "Facial Toner", "Example Vendor": "Pixi"},
    {"Item": "Foot Scrub", "Example Vendor": "The Body Shop"},
    {"Item": "Nose Strips", "Example Vendor": "Biore"},
    {"Item": "Lip Scrub", "Example Vendor": "Fresh"},
    {"Item": "Eye Patches", "Example Vendor": "Peter Thomas Roth"},
    {"Item": "Hair Detangler", "Example Vendor": "Johnson's"},
    {"Item": "Brow Kit", "Example Vendor": "Benefit"},
    {"Item": "Facial Roller", "Example Vendor": "Herbivore"},
    {"Item": "Shaving Gel", "Example Vendor": "Gillette"},
    {"Item": "Cuticle Remover", "Example Vendor": "Blue Cross"},
    {"Item": "Anti-Dandruff Shampoo", "Example Vendor": "Nizoral"},
    {"Item": "Lip Plumper", "Example Vendor": "Too Faced"},
    {"Item": "Facial Mist", "Example Vendor": "Mario Badescu"},
    {"Item": "Body Mist", "Example Vendor": "Victoria's Secret"},
    {"Item": "Manicure Set", "Example Vendor": "Seki Edge"},
    {"Item": "Hair Dryer", "Example Vendor": "Dyson"},
    {"Item": "Curling Iron", "Example Vendor": "Hot Tools"},
    {"Item": "Straightener", "Example Vendor": "ghd"},
    {"Item": "Electric Shaver", "Example Vendor": "Philips Norelco"},
    {"Item": "Foot Lotion", "Example Vendor": "Gold Bond"},
    {"Item": "Body Firming Cream", "Example Vendor": "Nivea"},
    {"Item": "Lash Glue", "Example Vendor": "DUO"},
    {"Item": "Hair Curl Cream", "Example Vendor": "DevaCurl"},
    {"Item": "Heat Protectant Spray", "Example Vendor": "TRESemme"},
    {"Item": "Facial Sunscreen", "Example Vendor": "EltaMD"},
    {"Item": "Anti-Frizz Serum", "Example Vendor": "John Frieda"},
    {"Item": "Waxing Kit", "Example Vendor": "Sally Hansen"},
    {"Item": "Facial Oil", "Example Vendor": "Sunday Riley"},
    {"Item": "After Sun Lotion", "Example Vendor": "Hawaiian Tropic"},
    {"Item": "Nail Polish Remover", "Example Vendor": "Zoya"},
    {"Item": "Bath Oil", "Example Vendor": "Kneipp"},
    {"Item": "Sleeping Mask", "Example Vendor": "Laneige"},
    {"Item": "Clay Mask", "Example Vendor": "Aztec Secret"},
    {"Item": "Lip Stain", "Example Vendor": "Benefit"},
    {"Item": "Eyebrow Dye", "Example Vendor": "RefectoCil"},
    {"Item": "Hair Bleach", "Example Vendor": "Manic Panic"},
    {"Item": "Foot Peel", "Example Vendor": "Baby Foot"},
    {"Item": "Shower Cap", "Example Vendor": "Drybar"},
    {"Item": "Nail Buffer", "Example Vendor": "Tweezerman"},
    {"Item": "Eye Makeup Remover", "Example Vendor": "Lancome"},
    {"Item": "Micellar Water", "Example Vendor": "Bioderma"},
    {"Item": "Hand Sanitizer", "Example Vendor": "Purell"},
    {"Item": "Cuticle Cream", "Example Vendor": "Burt's Bees"},
    {"Item": "Massage Oil", "Example Vendor": "Weleda"},
    {"Item": "Volumizing Spray", "Example Vendor": "Living Proof"},
    {"Item": "Hair Growth Serum", "Example Vendor": "Rogaine"},
    {"Item": "Nail Hardener", "Example Vendor": "Nailtiques"},
    {"Item": "Body Powder", "Example Vendor": "Gold Bond"},
    {"Item": "Eyelash Curler", "Example Vendor": "Shu Uemura"},
    {"Item": "Foot File", "Example Vendor": "Amope"},
    {"Item": "Brow Pencil", "Example Vendor": "NYX"},
    {"Item": "Hair Tonic", "Example Vendor": "Vaseline"},
    {"Item": "Beard Trimmer", "Example Vendor": "Wahl"},
    {"Item": "Nail Art Kit", "Example Vendor": "Kiss"},
    {"Item": "Depilatory Cream", "Example Vendor": "Veet"},
    {"Item": "Facial Epilator", "Example Vendor": "Braun"},
    {"Item": "Mud Mask", "Example Vendor": "Glamglow"},
    {"Item": "Lash Primer", "Example Vendor": "Lancome"},
    {"Item": "Bath Sponge", "Example Vendor": "EcoTools"},
    {"Item": "Makeup Setting Powder", "Example Vendor": "Coty"},
    {"Item": "Hand Lotion", "Example Vendor": "Jergens"},
    {"Item": "Exfoliating Brush", "Example Vendor": "Clarisonic"},
    {"Item": "Lip Plumping Gloss", "Example Vendor": "Dior"},
    {"Item": "Beard Wash", "Example Vendor": "Cremo"},
    {"Item": "Aromatherapy Diffuser", "Example Vendor": "Vitruvi"},
    {"Item": "Firming Lotion", "Example Vendor": "Nivea"},
    {"Item": "Hair Coloring Brush", "Example Vendor": "Color Wow"},
    {"Item": "Foot Soak", "Example Vendor": "Tea Tree Oil"},
    {"Item": "Facial Buffing Pads", "Example Vendor": "First Aid Beauty"},
    {"Item": "Nail Lacquer", "Example Vendor": "Essie"},
    {"Item": "Hair Straightening Brush", "Example Vendor": "Revlon"},
    {"Item": "Exfoliating Gloves", "Example Vendor": "Earth Therapeutics"},
    {"Item": "Face Blotting Paper", "Example Vendor": "Clean & Clear"},
    {"Item": "Dry Body Brush", "Example Vendor": "C.S.M"},
    {"Item": "Nail Repair Kit", "Example Vendor": "Orly"},
    {"Item": "Electric Toothbrush", "Example Vendor": "Oral-B"},
    {"Item": "Slow Cooker", "Example Vendor": "Crock-Pot"},
    {"Item": "Robot Vacuum", "Example Vendor": "iRobot Roomba"},
    {"Item": "Outdoor Fire Table", "Example Vendor": "Outland Living"},
    {"Item": "String Lights", "Example Vendor": "Brightown"},
    {"Item": "Garden Kneeler", "Example Vendor": "Ohuhu"},
    {"Item": "Portable Generator", "Example Vendor": "Honda"},
    {"Item": "Security Camera", "Example Vendor": "Arlo"},
    {"Item": "Steam Mop", "Example Vendor": "Bissell"},
    {"Item": "Herb Garden Kit", "Example Vendor": "AeroGarden"},
    {"Item": "Deck Box", "Example Vendor": "Keter"},
    {"Item": "Wireless Doorbell", "Example Vendor": "Ring"},
    {"Item": "Can Opener", "Example Vendor": "Hamilton Beach"},
    {"Item": "Folding Table", "Example Vendor": "Lifetime"},
    {"Item": "Compost Bin", "Example Vendor": "FCMP Outdoor"},
    {"Item": "Bonsai Tree", "Example Vendor": "Brussel's Bonsai"},
    {"Item": "Wine Cooler", "Example Vendor": "Frigidaire"},
    {"Item": "Solar Panels", "Example Vendor": "Renogy"},
    {"Item": "Indoor Grill", "Example Vendor": "Hamilton Beach"},
    {"Item": "Pasta Maker", "Example Vendor": "Marcato"},
    {"Item": "Drawer Organizer", "Example Vendor": "Bamboo Expandable"},
    {"Item": "Pool Float", "Example Vendor": "Intex"},
    {"Item": "Popcorn Maker", "Example Vendor": "Great Northern Popcorn Company"},
    {"Item": "Spice Rack", "Example Vendor": "Kamenstein"},
    {"Item": "Air Fryer", "Example Vendor": "Ninja"},
    {"Item": "Mosquito Trap", "Example Vendor": "Dynatrap"},
    {"Item": "Ice Cream Maker", "Example Vendor": "Cuisinart"},
    {"Item": "Garden Arch", "Example Vendor": "Gardman"},
    {"Item": "Cordless Drill", "Example Vendor": "DeWalt"},
    {"Item": "Wine Decanter", "Example Vendor": "Le Chateau"},
    {"Item": "Plant Stand", "Example Vendor": "Bamboo"},
    {"Item": "Bathroom Fan", "Example Vendor": "Panasonic"},
    {"Item": "Paper Towel Holder", "Example Vendor": "OXO"},
    {"Item": "Cheese Grater", "Example Vendor": "Zyliss"},
    {"Item": "Bathrobe", "Example Vendor": "Parachute"},
    {"Item": "Hedge Trimmer", "Example Vendor": "Greenworks"},
    {"Item": "Pie Dish", "Example Vendor": "Emile Henry"},
    {"Item": "Storage Ottoman", "Example Vendor": "Simpli Home"},
    {"Item": "Garden Statues", "Example Vendor": "Design Toscano"},
    {"Item": "Fountain Pen", "Example Vendor": "Pilot"},
    {"Item": "Sofa Cover", "Example Vendor": "Easy-Going"},
    {"Item": "Salad Spinner", "Example Vendor": "OXO"},
    {"Item": "Inflatable Pool", "Example Vendor": "Intex"},
    {"Item": "Tea Infuser", "Example Vendor": "Fred & Friends"},
    {"Item": "Bird Bath", "Example Vendor": "Best Choice Products"},
    {"Item": "Mandoline Slicer", "Example Vendor": "Mueller Austria"},
    {"Item": "Rain Gauge", "Example Vendor": "AcuRite"},
    {"Item": "Solar Garden Lights", "Example Vendor": "Gigalumi"},
    {"Item": "Pie Server", "Example Vendor": "OXO"},
    {"Item": "Orchid Pot", "Example Vendor": "Meshpot"},
    {"Item": "Fireplace Tools", "Example Vendor": "Amagabeli"},
    {"Item": "Pizza Stone", "Example Vendor": "Cuisinart"},
    {"Item": "Garden Flag", "Example Vendor": "Toland Home Garden"},
    {"Item": "Meat Thermometer", "Example Vendor": "ThermoPro"},
    {"Item": "Cheese Board", "Example Vendor": "Royal Craft Wood"},
    {"Item": "Wind Chimes", "Example Vendor": "Woodstock Chimes"},
    {"Item": "Juice Extractor", "Example Vendor": "Breville"},
    {"Item": "Folding Chair", "Example Vendor": "Cosco"},
    {"Item": "Towel Warmer", "Example Vendor": "Brookstone"},
    {"Item": "Birdhouse", "Example Vendor": "Nature's Way"},
    {"Item": "Kitchen Timer", "Example Vendor": "OXO"},
    {"Item": "Bath Caddy", "Example Vendor": "Royal Craft Wood"},
    {"Item": "Fruit Bowl", "Example Vendor": "Spectrum Diversified"},
    {"Item": "Knife Sharpener", "Example Vendor": "Chef'sChoice"},
    {"Item": "Garden Trowel", "Example Vendor": "Fiskars"},
    {"Item": "Bread Box", "Example Vendor": "Brabantia"},
    {"Item": "Wine Glasses", "Example Vendor": "Riedel"},
    {"Item": "Electric Blanket", "Example Vendor": "Sunbeam"},
    {"Item": "Garden Arbor", "Example Vendor": "New England Arbors"},
    {"Item": "Gravy Boat", "Example Vendor": "Noritake"},
    {"Item": "Tablecloth", "Example Vendor": "LinenTablecloth"},
    {"Item": "Mixing Bowls", "Example Vendor": "Pyrex"},
    {"Item": "Shoe Rack", "Example Vendor": "Seville Classics"},
    {"Item": "Garden Gnome", "Example Vendor": "GlitZGlam"},
    {"Item": "Sandwich Maker", "Example Vendor": "Hamilton Beach"},
    {"Item": "Pest Control", "Example Vendor": "Terro"},
    {"Item": "Carpet Cleaner", "Example Vendor": "Hoover"},
    {"Item": "Egg Cooker", "Example Vendor": "Dash"},
    {"Item": "Desk Fan", "Example Vendor": "Vornado"},
    {"Item": "Garden Edging", "Example Vendor": "Dimex"},
    {"Item": "Ice Maker", "Example Vendor": "GE"},
    {"Item": "Plant Saucer", "Example Vendor": "Curtis Wagner Plastics"},
    {"Item": "Bathroom Mirror", "Example Vendor": "Kohler"},
    {"Item": "Picnic Basket", "Example Vendor": "Picnic Time"},
    {"Item": "Teapot", "Example Vendor": "Tealyra"},
    {"Item": "Grill Brush", "Example Vendor": "Weber"},
    {"Item": "Rocking Chair", "Example Vendor": "POLYWOOD"},
    {"Item": "Sauté Pan", "Example Vendor": "T-fal"},
    {"Item": "Garden Boots", "Example Vendor": "Sloggers"},
    {"Item": "Soup Pot", "Example Vendor": "Le Creuset"},
    {"Item": "Toilet Brush", "Example Vendor": "OXO"},
    {"Item": "Mason Jars", "Example Vendor": "Ball"},
    {"Item": "Electric Fireplace", "Example Vendor": "Duraflame"},
    {"Item": "Gardening Hat", "Example Vendor": "Sloggers"},
    {"Item": "Pastry Brush", "Example Vendor": "OXO"},
    {"Item": "Bird Seed", "Example Vendor": "Wagner's"},
    {"Item": "Garden Lights", "Example Vendor": "Solpex"},
    {"Item": "Cake Stand", "Example Vendor": "Libbey"},
    {"Item": "Iron", "Example Vendor": "Rowenta"},
    {"Item": "Salad Bowl", "Example Vendor": "Lipper International"},
    {"Item": "Outdoor Rug", "Example Vendor": "Fab Habitat"},
    {"Item": "Kitchen Scale", "Example Vendor": "Etekcity"},
    {"Item": "Mulch", "Example Vendor": "Scotts"},
    {"Item": "Placemats", "Example Vendor": "DII"},
    {"Item": "Oil Diffuser", "Example Vendor": "VicTsing"},
    {"Item": "Garden Bench Cushion", "Example Vendor": "Pillow Perfect"},
    {"Item": "Herb Scissors", "Example Vendor": "Jenaluca"},
    {"Item": "Grill Mat", "Example Vendor": "Grillaholics"},
    {"Item": "Garden Tiller", "Example Vendor": "Sun Joe"}
]

# %%
# Creating a DataFrame
df_health_beauty = pd.DataFrame(health_beauty_items)
df_health_beauty['Items'] = df_health_beauty['Item'] + " " + df_health_beauty['Example Vendor']
df_health_beauty = df_health_beauty.drop({'Item', 'Example Vendor'}, axis=1)
df_health_beauty
# Out:
#                                    Items
# 0                        Shampoo Pantene
# 1            Conditioner Herbal Essences
# 2                     Toothpaste Colgate
# 3                         Body Wash Dove
# 4                   Moisturizer Cetaphil
# ..                                   ...
# 265                Oil Diffuser VicTsing
# 266  Garden Bench Cushion Pillow Perfect
# 267               Herb Scissors Jenaluca
# 268               Grill Mat Grillaholics
# 269                Garden Tiller Sun Joe
#
# [270 rows x 1 columns]

# %%
df_health_beauty.to_csv('health_beauty_datebase.csv', index=0)

# %% [markdown]
# ----

# %%
# List of electronics and appliances items with example vendors
electronics_items = [
    {"Item": "Smartphone", "Example Vendor": "Apple"},
    {"Item": "Laptop", "Example Vendor": "Dell"},
    {"Item": "Television", "Example Vendor": "Samsung"},
    {"Item": "Tablet", "Example Vendor": "Microsoft"},
    {"Item": "Wireless Headphones", "Example Vendor": "Sony"},
    {"Item": "Digital Camera", "Example Vendor": "Canon"},
    {"Item": "Smart Watch", "Example Vendor": "Garmin"},
    {"Item": "Bluetooth Speaker", "Example Vendor": "Bose"},
    {"Item": "E-Reader", "Example Vendor": "Amazon Kindle"},
    {"Item": "Microwave Oven", "Example Vendor": "Panasonic"},
    {"Item": "Refrigerator", "Example Vendor": "LG"},
    {"Item": "Washing Machine", "Example Vendor": "Whirlpool"},
    {"Item": "Vacuum Cleaner", "Example Vendor": "Dyson"},
    {"Item": "Air Purifier", "Example Vendor": "Honeywell"},
    {"Item": "Hair Dryer", "Example Vendor": "Conair"},
    {"Item": "Electric Kettle", "Example Vendor": "Russell Hobbs"},
    {"Item": "Food Processor", "Example Vendor": "Cuisinart"},
    {"Item": "Espresso Machine", "Example Vendor": "Breville"},
    {"Item": "Stand Mixer", "Example Vendor": "KitchenAid"},
    {"Item": "Rice Cooker", "Example Vendor": "Zojirushi"},
    {"Item": "Toaster", "Example Vendor": "Hamilton Beach"},
    {"Item": "Slow Cooker", "Example Vendor": "Crock-Pot"},
    {"Item": "Blender", "Example Vendor": "NutriBullet"},
    {"Item": "Portable Charger", "Example Vendor": "Anker"},
    {"Item": "Fitness Tracker", "Example Vendor": "Fitbit"},
    {"Item": "Gaming Console", "Example Vendor": "Nintendo"},
    {"Item": "Action Camera", "Example Vendor": "GoPro"},
    {"Item": "Smart Thermostat", "Example Vendor": "Nest"},
    {"Item": "Robot Vacuum", "Example Vendor": "iRobot"},
    {"Item": "Electric Toothbrush", "Example Vendor": "Oral-B"},
    {"Item": "Soundbar", "Example Vendor": "Sonos"},
    {"Item": "Wireless Router", "Example Vendor": "Netgear"},
    {"Item": "External Hard Drive", "Example Vendor": "Western Digital"},
    {"Item": "Smart Home Hub", "Example Vendor": "Google Home"},
    {"Item": "Electric Grill", "Example Vendor": "George Foreman"},
    {"Item": "Juicer", "Example Vendor": "Omega"},
    {"Item": "Steam Iron", "Example Vendor": "Rowenta"},
    {"Item": "Electric Shaver", "Example Vendor": "Philips"},
    {"Item": "Home Security Camera", "Example Vendor": "Arlo"},
    {"Item": "Graphic Tablet", "Example Vendor": "Wacom"},
    {"Item": "E-book Reader", "Example Vendor": "Kobo"},
    {"Item": "Dishwasher", "Example Vendor": "Bosch"},
    {"Item": "Air Fryer", "Example Vendor": "Ninja"},
    {"Item": "Electric Skillet", "Example Vendor": "Presto"},
    {"Item": "Portable Air Conditioner", "Example Vendor": "Honeywell"},
    {"Item": "Home Theater System", "Example Vendor": "Bose"},
    {"Item": "Smart Light Bulbs", "Example Vendor": "Philips Hue"},
    {"Item": "Sewing Machine", "Example Vendor": "Brother"},
    {"Item": "Induction Cooktop", "Example Vendor": "GE"},
    {"Item": "Digital Piano", "Example Vendor": "Yamaha"},
    {"Item": "VR Headset", "Example Vendor": "Oculus"},
    {"Item": "Electric Scooter", "Example Vendor": "Xiaomi"},
    {"Item": "Drone", "Example Vendor": "DJI"},
    {"Item": "Smart Lock", "Example Vendor": "August"},
    {"Item": "Range Hood", "Example Vendor": "Broan"},
    {"Item": "Waffle Maker", "Example Vendor": "Cuisinart"},
    {"Item": "Garment Steamer", "Example Vendor": "Jiffy"},
    {"Item": "Noise-Cancelling Headphones", "Example Vendor": "Bose"},
    {"Item": "Smart Scale", "Example Vendor": "Withings"},
    {"Item": "Smart Scale", "Example Vendor": "Withings"},
    {"Item": "3D Printer", "Example Vendor": "MakerBot"},
    {"Item": "Electric Blanket", "Example Vendor": "Sunbeam"},
    {"Item": "Solar Charger", "Example Vendor": "Anker"},
    {"Item": "Electric Mop", "Example Vendor": "Bissell"},
    {"Item": "Smart Plug", "Example Vendor": "TP-Link"},
    {"Item": "Humidifier", "Example Vendor": "Vicks"},
    {"Item": "Electric Pressure Cooker", "Example Vendor": "Instant Pot"},
    {"Item": "Car GPS", "Example Vendor": "Garmin"},
    {"Item": "Digital Voice Recorder", "Example Vendor": "Sony"},
    {"Item": "Streaming Media Player", "Example Vendor": "Roku"},
    {"Item": "Blood Pressure Monitor", "Example Vendor": "Omron"},
    {"Item": "Digital Photo Frame", "Example Vendor": "Nixplay"},
    {"Item": "Handheld Vacuum", "Example Vendor": "Black+Decker"},
    {"Item": "Weather Station", "Example Vendor": "AcuRite"},
    {"Item": "Satellite Radio", "Example Vendor": "SiriusXM"},
    {"Item": "Keyboard and Mouse Set", "Example Vendor": "Logitech"},
    {"Item": "Wi-Fi Range Extender", "Example Vendor": "TP-Link"},
    {"Item": "Mini Projector", "Example Vendor": "Anker"},
    {"Item": "Dash Cam", "Example Vendor": "Garmin"},
    {"Item": "Desktop Computer", "Example Vendor": "HP"},
    {"Item": "Baby Monitor", "Example Vendor": "Infant Optics"},
    {"Item": "Smart Doorbell", "Example Vendor": "Ring"},
    {"Item": "Ice Cream Maker", "Example Vendor": "Cuisinart"},
    {"Item": "Bread Maker", "Example Vendor": "Zojirushi"},
    {"Item": "Electric Wine Opener", "Example Vendor": "Oster"},
    {"Item": "Electric Can Opener", "Example Vendor": "Hamilton Beach"},
    {"Item": "Electric Shaver for Women", "Example Vendor": "Braun"},
    {"Item": "Portable DVD Player", "Example Vendor": "Sony"},
    {"Item": "Curling Iron", "Example Vendor": "Hot Tools"},
    {"Item": "LED Monitor", "Example Vendor": "Dell"},
    {"Item": "Digital SLR Camera", "Example Vendor": "Nikon"},
    {"Item": "CD Player", "Example Vendor": "Sony"},
    {"Item": "Computer Speakers", "Example Vendor": "Creative"},
    {"Item": "Smart Ring", "Example Vendor": "Motiv"},
    {"Item": "Electric Fireplace", "Example Vendor": "Duraflame"},
    {"Item": "Radar Detector", "Example Vendor": "Escort"},
    {"Item": "Smart Water Bottle", "Example Vendor": "Hidrate Spark"},
    {"Item": "Electric Pasta Maker", "Example Vendor": "Philips"},
    {"Item": "Electric Grill", "Example Vendor": "George Foreman"},
    {"Item": "Toaster Oven", "Example Vendor": "Black+Decker"},
    {"Item": "Dehumidifier", "Example Vendor": "Frigidaire"},
    {"Item": "Smart Indoor Garden", "Example Vendor": "Click & Grow"},
    {"Item": "Digital Scale", "Example Vendor": "Etekcity"},
    {"Item": "Cordless Phone", "Example Vendor": "Panasonic"},
    {"Item": "Portable Air Cooler", "Example Vendor": "Honeywell"},
    {"Item": "Digital Thermostat", "Example Vendor": "Honeywell"},
    {"Item": "Water Filter Pitcher", "Example Vendor": "Brita"},
    {"Item": "Noise Machine", "Example Vendor": "Marpac"},
    {"Item": "Electric Massager", "Example Vendor": "Theragun"},
    {"Item": "Inkjet Printer", "Example Vendor": "Epson"},
    {"Item": "Electric Tea Infuser", "Example Vendor": "Breville"},
    {"Item": "Security System", "Example Vendor": "SimpliSafe"},
    {"Item": "Digital Mixer", "Example Vendor": "Behringer"},
    {"Item": "Karaoke Machine", "Example Vendor": "Singing Machine"},
    {"Item": "Electronic Drum Set", "Example Vendor": "Alesis"},
    {"Item": "Electric Piano", "Example Vendor": "Casio"},
    {"Item": "Electric Piano", "Example Vendor": "Casio"},
    {"Item": "Portable Speaker", "Example Vendor": "JBL"},
    {"Item": "Wireless Earbuds", "Example Vendor": "Apple AirPods"},
    {"Item": "Smart Glasses", "Example Vendor": "Vuzix"},
    {"Item": "Electric Skateboard", "Example Vendor": "Boosted"},
    {"Item": "Smart Mug", "Example Vendor": "Ember"},
    {"Item": "Laser Printer", "Example Vendor": "Brother"},
    {"Item": "Fitness Watch", "Example Vendor": "Suunto"},
    {"Item": "Robot Mop", "Example Vendor": "Braava"},
    {"Item": "Digital Notepad", "Example Vendor": "Remarkable"},
    {"Item": "Smart Light Switch", "Example Vendor": "Lutron"},
    {"Item": "Gaming Laptop", "Example Vendor": "Alienware"},
    {"Item": "Electric Bike", "Example Vendor": "Rad Power Bikes"},
    {"Item": "Drone with Camera", "Example Vendor": "Parrot"},
    {"Item": "Digital Multimeter", "Example Vendor": "Fluke"},
    {"Item": "Smart Garden", "Example Vendor": "AeroGarden"},
    {"Item": "Portable Solar Panel", "Example Vendor": "Goal Zero"},
    {"Item": "Digital Video Recorder", "Example Vendor": "TiVo"},
    {"Item": "Game Console Controller", "Example Vendor": "Sony DualShock"},
    {"Item": "Smart Thermostat", "Example Vendor": "Ecobee"},
    {"Item": "Wireless Charging Pad", "Example Vendor": "Belkin"},
    {"Item": "Electric Wine Cooler", "Example Vendor": "Wine Enthusiast"},
    {"Item": "Gaming PC", "Example Vendor": "CyberPowerPC"},
    {"Item": "Smart Air Fryer", "Example Vendor": "Cosori"},
    {"Item": "Digital Keyboard", "Example Vendor": "Roland"},
    {"Item": "Smart Lighting Kit", "Example Vendor": "Philips Hue"},
    {"Item": "Electric Shaver", "Example Vendor": "Braun"},
    {"Item": "Wireless Gaming Mouse", "Example Vendor": "Razer"},
    {"Item": "Electric Blanket", "Example Vendor": "Biddeford"},
    {"Item": "Smart Body Analyzer", "Example Vendor": "Qardio"},
    {"Item": "Electric Fondue Pot", "Example Vendor": "Cuisinart"},
    {"Item": "Ergonomic Keyboard", "Example Vendor": "Microsoft"},
    {"Item": "Smart Coffee Maker", "Example Vendor": "Keurig"},
    {"Item": "Wireless Home Security System", "Example Vendor": "ADT"},
    {"Item": "Electric Pressure Washer", "Example Vendor": "Sun Joe"},
    {"Item": "Smart Baby Monitor", "Example Vendor": "Nanit"},
    {"Item": "Portable Power Station", "Example Vendor": "Jackery"},
    {"Item": "Digital Oscilloscope", "Example Vendor": "Rigol"},
    {"Item": "Smart Bathroom Scale", "Example Vendor": "Eufy"},
    {"Item": "Electronic Keyboard", "Example Vendor": "Korg"},
    {"Item": "Wi-Fi Smart Plug", "Example Vendor": "Kasa"},
    {"Item": "Portable PA System", "Example Vendor": "Bose"},
    {"Item": "Smart Door Lock", "Example Vendor": "Schlage"},
    {"Item": "Robot Pet", "Example Vendor": "Sony Aibo"},
    {"Item": "Electronic Dart Board", "Example Vendor": "Arachnid"},
    {"Item": "Wireless Sound System", "Example Vendor": "Sonos"},
    {"Item": "Electric Can Opener", "Example Vendor": "Proctor Silex"},
    {"Item": "Digital Picture Frame", "Example Vendor": "Pix-Star"},
    {"Item": "Electric Water Kettle", "Example Vendor": "Ovente"},
    {"Item": "Smart Home Security Camera", "Example Vendor": "Wyze Cam"},
    {"Item": "Digital Audio Recorder", "Example Vendor": "Zoom"}
]

# %%
# Creating a DataFrame
df_electronics = pd.DataFrame(electronics_items)
df_electronics['Items'] = df_electronics['Item'] + " " + df_electronics['Example Vendor']
df_electronics = df_electronics.drop({'Item', 'Example Vendor'}, axis=1)
df_electronics
# Out:
#                                    Items
# 0                       Smartphone Apple
# 1                            Laptop Dell
# 2                     Television Samsung
# 3                       Tablet Microsoft
# 4               Wireless Headphones Sony
# ..                                   ...
# 162    Electric Can Opener Proctor Silex
# 163       Digital Picture Frame Pix-Star
# 164         Electric Water Kettle Ovente
# 165  Smart Home Security Camera Wyze Cam
# 166          Digital Audio Recorder Zoom
#
# [167 rows x 1 columns]

# %%
df_electronics.to_csv('electronics_datebase.csv', index=0)

# %% [markdown]
# ----

# %%
# List of home and garden items with example vendors
home_garden_items = [
    {"Item": "Lawn Mower", "Example Vendor": "Husqvarna"},
    {"Item": "Sofa", "Example Vendor": "IKEA"},
    {"Item": "Coffee Maker", "Example Vendor": "Keurig"},
    {"Item": "Bed Frame", "Example Vendor": "Wayfair"},
    {"Item": "Garden Hose", "Example Vendor": "Gardena"},
    {"Item": "Dining Table", "Example Vendor": "Ashley Furniture"},
    {"Item": "Blender", "Example Vendor": "Vitamix"},
    {"Item": "Area Rug", "Example Vendor": "Ruggable"},
    {"Item": "Desk Lamp", "Example Vendor": "Philips"},
    {"Item": "Patio Set", "Example Vendor": "Home Depot"},
    {"Item": "Shower Curtain", "Example Vendor": "Bed Bath & Beyond"},
    {"Item": "Wall Clock", "Example Vendor": "Casio"},
    {"Item": "Tool Set", "Example Vendor": "Craftsman"},
    {"Item": "Microwave Oven", "Example Vendor": "Panasonic"},
    {"Item": "BBQ Grill", "Example Vendor": "Weber"},
    {"Item": "Vacuum Cleaner", "Example Vendor": "Dyson"},
    {"Item": "Picture Frame", "Example Vendor": "Michael's"},
    {"Item": "Plant Pot", "Example Vendor": "Lechuza"},
    {"Item": "Bookshelf", "Example Vendor": "Sauder"},
    {"Item": "Ceiling Fan", "Example Vendor": "Hunter"},
    {"Item": "Toaster", "Example Vendor": "Cuisinart"},
    {"Item": "Curtains", "Example Vendor": "Ikea"},
    {"Item": "Fire Pit", "Example Vendor": "Solo Stove"},
    {"Item": "Dishwasher", "Example Vendor": "Bosch"},
    {"Item": "Garden Shovel", "Example Vendor": "Fiskars"},
    {"Item": "Television", "Example Vendor": "Samsung"},
    {"Item": "Air Purifier", "Example Vendor": "Honeywell"},
    {"Item": "Bedding Set", "Example Vendor": "Brooklinen"},
    {"Item": "Electric Kettle", "Example Vendor": "Breville"},
    {"Item": "Floor Lamp", "Example Vendor": "Ikea"},
    {"Item": "Recliner Chair", "Example Vendor": "La-Z-Boy"},
    {"Item": "Food Processor", "Example Vendor": "KitchenAid"},
    {"Item": "Throw Pillows", "Example Vendor": "Pottery Barn"},
    {"Item": "Leaf Blower", "Example Vendor": "Black+Decker"},
    {"Item": "Pressure Washer", "Example Vendor": "Kärcher"},
    {"Item": "Fridge", "Example Vendor": "LG"},
    {"Item": "Garden Bench", "Example Vendor": "Plow & Hearth"},
    {"Item": "Wall Art", "Example Vendor": "Society6"},
    {"Item": "Juicer", "Example Vendor": "Omega"},
    {"Item": "Humidifier", "Example Vendor": "Vicks"},
    {"Item": "Cutlery Set", "Example Vendor": "Henckels"},
    {"Item": "Storage Bins", "Example Vendor": "The Container Store"},
    {"Item": "Thermostat", "Example Vendor": "Nest"},
    {"Item": "Door Mat", "Example Vendor": "Frontgate"},
    {"Item": "Bath Towels", "Example Vendor": "Parachute"},
    {"Item": "Espresso Machine", "Example Vendor": "De'Longhi"},
    {"Item": "Garden Gloves", "Example Vendor": "Wells Lamont"},
    {"Item": "Space Heater", "Example Vendor": "Lasko"},
    {"Item": "Oven Range", "Example Vendor": "GE"},
    {"Item": "Nightstand", "Example Vendor": "West Elm"},
    {"Item": "Lawn Sprinkler", "Example Vendor": "Rain Bird"},
    {"Item": "Sewing Machine", "Example Vendor": "Brother"},
    {"Item": "Smart Speaker", "Example Vendor": "Amazon Echo"},
    {"Item": "Paint", "Example Vendor": "Benjamin Moore"},
    {"Item": "Garden Fertilizer", "Example Vendor": "Miracle-Gro"},
    {"Item": "Clothes Dryer", "Example Vendor": "Whirlpool"},
    {"Item": "Office Chair", "Example Vendor": "Herman Miller"},
    {"Item": "Sleeping Bag", "Example Vendor": "Coleman"},
    {"Item": "Lawn Edger", "Example Vendor": "Worx"},
    {"Item": "Watering Can", "Example Vendor": "Haws"},
    {"Item": "Trash Can", "Example Vendor": "Simplehuman"},
    {"Item": "Ironing Board", "Example Vendor": "Brabantia"},
    {"Item": "Floor Cleaner", "Example Vendor": "Bona"},
    {"Item": "Hand Mixer", "Example Vendor": "Hamilton Beach"},
    {"Item": "Hammock", "Example Vendor": "ENO"},
    {"Item": "Garden Shears", "Example Vendor": "Gardena"},
    {"Item": "Bread Maker", "Example Vendor": "Zojirushi"},
    {"Item": "Shower Head", "Example Vendor": "Moen"},
    {"Item": "Wallpaper", "Example Vendor": "Graham & Brown"},
    {"Item": "Cookware Set", "Example Vendor": "All-Clad"},
    {"Item": "Duvet Cover", "Example Vendor": "Casper"},
    {"Item": "Air Conditioner", "Example Vendor": "Frigidaire"},
    {"Item": "Weed Trimmer", "Example Vendor": "Stihl"},
    {"Item": "Candle Holder", "Example Vendor": "Yankee Candle"},
    {"Item": "Food Scale", "Example Vendor": "OXO"},
    {"Item": "Patio Heater", "Example Vendor": "Fire Sense"},
    {"Item": "Barbecue Tools", "Example Vendor": "Grillaholics"},
    {"Item": "Crockpot", "Example Vendor": "Crock-Pot"},
    {"Item": "Garden Planter", "Example Vendor": "Keter"},
    {"Item": "Wine Rack", "Example Vendor": "J.K. Adams"},
    {"Item": "Bathroom Scale", "Example Vendor": "Fitbit"},
    {"Item": "Garden Tractor", "Example Vendor": "John Deere"},
    {"Item": "Vacuum Sealer", "Example Vendor": "Foodsaver"},
    {"Item": "Bedspread", "Example Vendor": "Quilted Northern"},
    {"Item": "Desk Organizer", "Example Vendor": "Madesmart"},
    {"Item": "Ladder", "Example Vendor": "Werner"},
    {"Item": "Bird Feeder", "Example Vendor": "Perky-Pet"},
    {"Item": "Rice Cooker", "Example Vendor": "Aroma"},
    {"Item": "Lamp Shade", "Example Vendor": "West Elm"},
    {"Item": "Garden Sprayer", "Example Vendor": "Chapin"},
    {"Item": "Storage Shed", "Example Vendor": "Rubbermaid"},
    {"Item": "Blinds", "Example Vendor": "Levolor"},
    {"Item": "Fireplace", "Example Vendor": "Dimplex"},
    {"Item": "Mop", "Example Vendor": "Swiffer"},
    {"Item": "Grill Cover", "Example Vendor": "Classic Accessories"},
    {"Item": "Chandelier", "Example Vendor": "Kichler"},
    {"Item": "Outdoor Lighting", "Example Vendor": "Philips Hue"},
    {"Item": "Garden Cart", "Example Vendor": "Gorilla Carts"},
    {"Item": "Stand Mixer", "Example Vendor": "KitchenAid"},
    {"Item": "Workbench", "Example Vendor": "Gladiator"},
    {"Item": "Doormat", "Example Vendor": "Chilewich"},
    {"Item": "Gardening Gloves", "Example Vendor": "Atlas"},
    {"Item": "Electric Grill", "Example Vendor": "George Foreman"},
    {"Item": "Curtain Rod", "Example Vendor": "Umbra"},
    {"Item": "Lawn Aerator", "Example Vendor": "Agri-Fab"},
    {"Item": "Kettle", "Example Vendor": "Le Creuset"},
    {"Item": "Bath Mat", "Example Vendor": "Gorilla Grip"},
    {"Item": "Fire Extinguisher", "Example Vendor": "Kidde"},
    {"Item": "Waffle Maker", "Example Vendor": "Cuisinart"},
    {"Item": "Pillowcase", "Example Vendor": "Silvon"},
    {"Item": "Yoga Mat", "Example Vendor": "Manduka"},
    {"Item": "Electric Toothbrush", "Example Vendor": "Oral-B"},
    {"Item": "Slow Cooker", "Example Vendor": "Crock-Pot"},
    {"Item": "Robot Vacuum", "Example Vendor": "iRobot Roomba"},
    {"Item": "Outdoor Fire Table", "Example Vendor": "Outland Living"},
    {"Item": "String Lights", "Example Vendor": "Brightown"},
    {"Item": "Garden Kneeler", "Example Vendor": "Ohuhu"},
    {"Item": "Portable Generator", "Example Vendor": "Honda"},
    {"Item": "Security Camera", "Example Vendor": "Arlo"},
    {"Item": "Steam Mop", "Example Vendor": "Bissell"},
    {"Item": "Herb Garden Kit", "Example Vendor": "AeroGarden"},
    {"Item": "Deck Box", "Example Vendor": "Keter"},
    {"Item": "Wireless Doorbell", "Example Vendor": "Ring"},
    {"Item": "Can Opener", "Example Vendor": "Hamilton Beach"},
    {"Item": "Folding Table", "Example Vendor": "Lifetime"},
    {"Item": "Compost Bin", "Example Vendor": "FCMP Outdoor"},
    {"Item": "Bonsai Tree", "Example Vendor": "Brussel's Bonsai"},
    {"Item": "Wine Cooler", "Example Vendor": "Frigidaire"},
    {"Item": "Solar Panels", "Example Vendor": "Renogy"},
    {"Item": "Indoor Grill", "Example Vendor": "Hamilton Beach"},
    {"Item": "Pasta Maker", "Example Vendor": "Marcato"},
    {"Item": "Drawer Organizer", "Example Vendor": "Bamboo Expandable"},
    {"Item": "Pool Float", "Example Vendor": "Intex"},
    {"Item": "Popcorn Maker", "Example Vendor": "Great Northern Popcorn Company"},
    {"Item": "Spice Rack", "Example Vendor": "Kamenstein"},
    {"Item": "Air Fryer", "Example Vendor": "Ninja"},
    {"Item": "Mosquito Trap", "Example Vendor": "Dynatrap"},
    {"Item": "Ice Cream Maker", "Example Vendor": "Cuisinart"},
    {"Item": "Garden Arch", "Example Vendor": "Gardman"},
    {"Item": "Cordless Drill", "Example Vendor": "DeWalt"},
    {"Item": "Wine Decanter", "Example Vendor": "Le Chateau"},
    {"Item": "Plant Stand", "Example Vendor": "Bamboo"},
    {"Item": "Bathroom Fan", "Example Vendor": "Panasonic"},
    {"Item": "Paper Towel Holder", "Example Vendor": "OXO"},
    {"Item": "Cheese Grater", "Example Vendor": "Zyliss"},
    {"Item": "Bathrobe", "Example Vendor": "Parachute"},
    {"Item": "Hedge Trimmer", "Example Vendor": "Greenworks"},
    {"Item": "Pie Dish", "Example Vendor": "Emile Henry"},
    {"Item": "Storage Ottoman", "Example Vendor": "Simpli Home"},
    {"Item": "Garden Statues", "Example Vendor": "Design Toscano"},
    {"Item": "Fountain Pen", "Example Vendor": "Pilot"},
    {"Item": "Sofa Cover", "Example Vendor": "Easy-Going"},
    {"Item": "Salad Spinner", "Example Vendor": "OXO"},
    {"Item": "Inflatable Pool", "Example Vendor": "Intex"},
    {"Item": "Tea Infuser", "Example Vendor": "Fred & Friends"},
    {"Item": "Bird Bath", "Example Vendor": "Best Choice Products"},
    {"Item": "Mandoline Slicer", "Example Vendor": "Mueller Austria"},
    {"Item": "Rain Gauge", "Example Vendor": "AcuRite"},
    {"Item": "Solar Garden Lights", "Example Vendor": "Gigalumi"},
    {"Item": "Pie Server", "Example Vendor": "OXO"},
    {"Item": "Orchid Pot", "Example Vendor": "Meshpot"},
    {"Item": "Fireplace Tools", "Example Vendor": "Amagabeli"},
    {"Item": "Pizza Stone", "Example Vendor": "Cuisinart"},
    {"Item": "Garden Flag", "Example Vendor": "Toland Home Garden"},
    {"Item": "Meat Thermometer", "Example Vendor": "ThermoPro"},
    {"Item": "Cheese Board", "Example Vendor": "Royal Craft Wood"},
    {"Item": "Cheese Board", "Example Vendor": "Royal Craft Wood"},
    {"Item": "Wind Chimes", "Example Vendor": "Woodstock Chimes"},
    {"Item": "Juice Extractor", "Example Vendor": "Breville"},
    {"Item": "Folding Chair", "Example Vendor": "Cosco"},
    {"Item": "Towel Warmer", "Example Vendor": "Brookstone"},
    {"Item": "Birdhouse", "Example Vendor": "Nature's Way"},
    {"Item": "Kitchen Timer", "Example Vendor": "OXO"},
    {"Item": "Bath Caddy", "Example Vendor": "Royal Craft Wood"},
    {"Item": "Fruit Bowl", "Example Vendor": "Spectrum Diversified"},
    {"Item": "Knife Sharpener", "Example Vendor": "Chef'sChoice"},
    {"Item": "Garden Trowel", "Example Vendor": "Fiskars"},
    {"Item": "Bread Box", "Example Vendor": "Brabantia"},
    {"Item": "Wine Glasses", "Example Vendor": "Riedel"},
    {"Item": "Electric Blanket", "Example Vendor": "Sunbeam"},
    {"Item": "Garden Arbor", "Example Vendor": "New England Arbors"},
    {"Item": "Gravy Boat", "Example Vendor": "Noritake"},
    {"Item": "Tablecloth", "Example Vendor": "LinenTablecloth"},
    {"Item": "Mixing Bowls", "Example Vendor": "Pyrex"},
    {"Item": "Shoe Rack", "Example Vendor": "Seville Classics"},
    {"Item": "Garden Gnome", "Example Vendor": "GlitZGlam"},
    {"Item": "Sandwich Maker", "Example Vendor": "Hamilton Beach"},
    {"Item": "Pest Control", "Example Vendor": "Terro"},
    {"Item": "Carpet Cleaner", "Example Vendor": "Hoover"},
    {"Item": "Egg Cooker", "Example Vendor": "Dash"},
    {"Item": "Desk Fan", "Example Vendor": "Vornado"},
    {"Item": "Garden Edging", "Example Vendor": "Dimex"},
    {"Item": "Ice Maker", "Example Vendor": "GE"},
    {"Item": "Plant Saucer", "Example Vendor": "Curtis Wagner Plastics"},
    {"Item": "Bathroom Mirror", "Example Vendor": "Kohler"},
    {"Item": "Picnic Basket", "Example Vendor": "Picnic Time"},
    {"Item": "Teapot", "Example Vendor": "Tealyra"},
    {"Item": "Grill Brush", "Example Vendor": "Weber"},
    {"Item": "Rocking Chair", "Example Vendor": "POLYWOOD"},
    {"Item": "Sauté Pan", "Example Vendor": "T-fal"},
    {"Item": "Garden Boots", "Example Vendor": "Sloggers"},
    {"Item": "Soup Pot", "Example Vendor": "Le Creuset"},
    {"Item": "Toilet Brush", "Example Vendor": "OXO"},
    {"Item": "Mason Jars", "Example Vendor": "Ball"},
    {"Item": "Electric Fireplace", "Example Vendor": "Duraflame"},
    {"Item": "Gardening Hat", "Example Vendor": "Sloggers"},
    {"Item": "Pastry Brush", "Example Vendor": "OXO"},
    {"Item": "Bird Seed", "Example Vendor": "Wagner's"},
    {"Item": "Garden Lights", "Example Vendor": "Solpex"},
    {"Item": "Cake Stand", "Example Vendor": "Libbey"},
    {"Item": "Iron", "Example Vendor": "Rowenta"},
    {"Item": "Salad Bowl", "Example Vendor": "Lipper International"},
    {"Item": "Outdoor Rug", "Example Vendor": "Fab Habitat"},
    {"Item": "Kitchen Scale", "Example Vendor": "Etekcity"},
    {"Item": "Mulch", "Example Vendor": "Scotts"},
    {"Item": "Placemats", "Example Vendor": "DII"},
    {"Item": "Oil Diffuser", "Example Vendor": "VicTsing"},
    {"Item": "Garden Bench Cushion", "Example Vendor": "Pillow Perfect"},
    {"Item": "Herb Scissors", "Example Vendor": "Jenaluca"},
    {"Item": "Grill Mat", "Example Vendor": "Grillaholics"},
    {"Item": "Garden Tiller", "Example Vendor": "Sun Joe"}
]

# %%
import pandas as pd

df_home_garden = pd.DataFrame(home_garden_items)
# Assuming df_home_garden is your DataFrame
df_home_garden['Items'] = df_home_garden['Item'] + " " + df_home_garden['Example Vendor']

# Dropping the columns 'Item' and 'Example Vendor'
df_home_garden = df_home_garden.drop(['Item', 'Example Vendor'], axis=1)

# Applying pd.unique() to the 'new' column of the DataFrame
unique_values = pd.unique(df_home_garden['Items'])
len(unique_values)
# Out:
# 220

# %%
df_home_garden = pd.DataFrame(unique_values, columns=['Items'])
df_home_garden
# Out:
#                                    Items
# 0                   Lawn Mower Husqvarna
# 1                              Sofa IKEA
# 2                    Coffee Maker Keurig
# 3                      Bed Frame Wayfair
# 4                    Garden Hose Gardena
# ..                                   ...
# 215                Oil Diffuser VicTsing
# 216  Garden Bench Cushion Pillow Perfect
# 217               Herb Scissors Jenaluca
# 218               Grill Mat Grillaholics
# 219                Garden Tiller Sun Joe
#
# [220 rows x 1 columns]

# %%
df_home_garden.to_csv('home_garden_datebase.csv', index=0)

# %% [markdown]
# ---

# %%
# List of entertainment and leisure items and example vendors
entertainment_items = [
    {"Item": "Movie Tickets", "Example Vendor": "AMC Theatres"},
    {"Item": "Video Game Console", "Example Vendor": "Sony (PlayStation)"},
    {"Item": "Streaming Service Subscription", "Example Vendor": "Netflix"},
    {"Item": "Board Games", "Example Vendor": "Hasbro"},
    {"Item": "E-Book Reader", "Example Vendor": "Amazon (Kindle)"},
    {"Item": "Music Streaming Subscription", "Example Vendor": "Spotify"},
    {"Item": "Fitness Club Membership", "Example Vendor": "Planet Fitness"},
    {"Item": "Bicycle", "Example Vendor": "Trek"},
    {"Item": "Yoga Classes", "Example Vendor": "CorePower Yoga"},
    {"Item": "Concert Tickets", "Example Vendor": "Ticketmaster"},
    {"Item": "Museum Pass", "Example Vendor": "Smithsonian Institution"},
    {"Item": "Theme Park Tickets", "Example Vendor": "Disneyland"},
    {"Item": "Golf Clubs", "Example Vendor": "Callaway"},
    {"Item": "Acoustic Guitar", "Example Vendor": "Yamaha"},
    {"Item": "Digital Camera", "Example Vendor": "Canon"},
    {"Item": "Camping Gear", "Example Vendor": "REI"},
    {"Item": "Ski Pass", "Example Vendor": "Vail Resorts"},
    {"Item": "Aquarium Membership", "Example Vendor": "Monterey Bay Aquarium"},
    {"Item": "Art Supplies", "Example Vendor": "Blick Art Materials"},
    {"Item": "Puzzle", "Example Vendor": "Ravensburger"},
    {"Item": "Dance Classes", "Example Vendor": "Arthur Murray"},
    {"Item": "Karaoke Machine", "Example Vendor": "Singing Machine"},
    {"Item": "Magazine Subscription", "Example Vendor": "National Geographic"},
    {"Item": "Surfboard", "Example Vendor": "Quiksilver"},
    {"Item": "RC Cars", "Example Vendor": "Traxxas"},
    {"Item": "Zoo Tickets", "Example Vendor": "San Diego Zoo"},
    {"Item": "Electric Guitar", "Example Vendor": "Fender"},
    {"Item": "Bowling Alley Pass", "Example Vendor": "Bowlero"},
    {"Item": "Cruise Tickets", "Example Vendor": "Royal Caribbean"},
    {"Item": "Fishing Rod", "Example Vendor": "Shimano"},
    {"Item": "Rock Climbing Gym Membership", "Example Vendor": "Touchstone Climbing"},
    {"Item": "Comic Books", "Example Vendor": "Marvel Comics"},
    {"Item": "Piano", "Example Vendor": "Steinway & Sons"},
    {"Item": "Online Gaming Subscription", "Example Vendor": "Xbox Live"},
    {"Item": "Botanical Garden Membership", "Example Vendor": "New York Botanical Garden"},
    {"Item": "Kayak", "Example Vendor": "Hobie"},
    {"Item": "Home Theater System", "Example Vendor": "Bose"},
    {"Item": "Vinyl Records", "Example Vendor": "Vinyl Me, Please"},
    {"Item": "Knitting Supplies", "Example Vendor": "Lion Brand Yarn"},
    {"Item": "Scrapbooking Materials", "Example Vendor": "Michaels"},
    {"Item": "Cooking Classes", "Example Vendor": "Sur La Table"},
    {"Item": "Snorkeling Gear", "Example Vendor": "Cressi"},
    {"Item": "Model Trains", "Example Vendor": "Hornby"},
    {"Item": "Theater Show Tickets", "Example Vendor": "Broadway.com"},
    {"Item": "Jigsaw Puzzles", "Example Vendor": "Jiggy"},
    {"Item": "Pottery Classes", "Example Vendor": "The Clay Studio"},
    {"Item": "Wine Tasting Experience", "Example Vendor": "Napa Valley Wine Tours"},
    {"Item": "Drone", "Example Vendor": "DJI"},
    {"Item": "Archery Equipment", "Example Vendor": "Archery World"},
    {"Item": "Photography Classes", "Example Vendor": "Nikon School"},
    {"Item": "Paintball Equipment", "Example Vendor": "Tippmann"},
    {"Item": "Home Brewing Kit", "Example Vendor": "Northern Brewer"},
    {"Item": "Gardening Tools", "Example Vendor": "Fiskars"},
    {"Item": "Virtual Reality Headset", "Example Vendor": "Oculus Rift"},
    {"Item": "Chess Set", "Example Vendor": "House of Staunton"},
    {"Item": "Kite", "Example Vendor": "Prism Kite Technology"},
    {"Item": "Language Learning Software", "Example Vendor": "Rosetta Stone"},
    {"Item": "Sewing Machine", "Example Vendor": "Brother"},
    {"Item": "Telescope", "Example Vendor": "Celestron"},
    {"Item": "Magic Tricks Set", "Example Vendor": "Murphy's Magic"},
    {"Item": "Bird Watching Binoculars", "Example Vendor": "Nikon"},
    {"Item": "Scuba Diving Lessons", "Example Vendor": "PADI"},
    {"Item": "Graphic Novels", "Example Vendor": "DC Comics"},
    {"Item": "Skateboard", "Example Vendor": "Element"},
    {"Item": "Audiobook Subscription", "Example Vendor": "Audible"},
    {"Item": "Trampoline", "Example Vendor": "Skywalker Trampolines"},
    {"Item": "Art Class Subscription", "Example Vendor": "Skillshare"},
    {"Item": "Hiking Trails Guidebook", "Example Vendor": "Lonely Planet"},
    {"Item": "Stand Up Paddleboard", "Example Vendor": "Bote"},
    {"Item": "Movie Streaming Device", "Example Vendor": "Roku"},
    {"Item": "Guitar Lessons", "Example Vendor": "Fender Play"},
    {"Item": "Roller Skates", "Example Vendor": "Moxi Skates"},
    {"Item": "Bonsai Tree Kit", "Example Vendor": "Brussel's Bonsai"},
    {"Item": "Digital Art Tablet", "Example Vendor": "Wacom"},
    {"Item": "Mountain Bike", "Example Vendor": "Giant"},
    {"Item": "Photography Course", "Example Vendor": "MasterClass"},
    {"Item": "Astrology Software", "Example Vendor": "TimePassages"},
    {"Item": "Board Game Cafe Membership", "Example Vendor": "Snakes & Lattes"},
    {"Item": "Racing Simulator", "Example Vendor": "Logitech G"},
    {"Item": "Laser Tag Set", "Example Vendor": "Nerf"},
    {"Item": "Model Building Kits", "Example Vendor": "LEGO"},
    {"Item": "Escape Room Experience", "Example Vendor": "The Escape Game"},
    {"Item": "Ceramics Workshop", "Example Vendor": "Color Me Mine"},
    {"Item": "Beach Volleyball Set", "Example Vendor": "Wilson"},
    {"Item": "Historical Tour Tickets", "Example Vendor": "Viator"},
    {"Item": "DIY Crafting Kit", "Example Vendor": "Etsy"},
    {"Item": "Orchestra Concert Tickets", "Example Vendor": "Berlin Philharmonic"},
    {"Item": "Comic Con Tickets", "Example Vendor": "San Diego Comic-Con"},
    {"Item": "Baking Supplies", "Example Vendor": "King Arthur Baking"},
    {"Item": "Sudoku Book", "Example Vendor": "Will Shortz"},
    {"Item": "Crossword Puzzle Subscription", "Example Vendor": "The New York Times"},
    {"Item": "Home Aquarium", "Example Vendor": "Aqueon"},
    {"Item": "VR Game", "Example Vendor": "Beat Saber"},
    {"Item": "Travel Guide Subscription", "Example Vendor": "Lonely Planet"},
    {"Item": "Hot Air Balloon Ride", "Example Vendor": "Balloon Adventures"},
    {"Item": "Collectible Card Games", "Example Vendor": "Magic: The Gathering"},
    {"Item": "Smart TV", "Example Vendor": "Samsung"},
    {"Item": "Musical Theater Classes", "Example Vendor": "Broadway Workshop"},
    {"Item": "Digital Piano", "Example Vendor": "Casio"},
    {"Item": "Kiteboarding Lessons", "Example Vendor": "REAL Kiteboarding"},
    {"Item": "Painting Set", "Example Vendor": "Bob Ross"},
    {"Item": "Paragliding Experience", "Example Vendor": "Flytec"},
    {"Item": "Dungeons & Dragons Set", "Example Vendor": "Wizards of the Coast"},
    {"Item": "Harmonica", "Example Vendor": "Hohner"},
    {"Item": "Ice Skating Lessons", "Example Vendor": "Ice Skating Institute"},
    {"Item": "Hot Yoga Classes", "Example Vendor": "Bikram Yoga"},
    {"Item": "Indoor Skydiving", "Example Vendor": "iFLY"},
    {"Item": "Rock Band Video Game", "Example Vendor": "Harmonix"},
    {"Item": "Herbal Tea Sampler", "Example Vendor": "Teavana"},
    {"Item": "Herbal Tea Sampler", "Example Vendor": "Teavana"},
    {"Item": "Mini Golf Pass", "Example Vendor": "Pirate's Cove"},
    {"Item": "Book Club Membership", "Example Vendor": "Book of the Month"},
    {"Item": "DIY Woodworking Kit", "Example Vendor": "Rockler"},
    {"Item": "Amusement Arcade Tokens", "Example Vendor": "Dave & Buster's"},
    {"Item": "Online Cooking Classes", "Example Vendor": "Gordon Ramsay's MasterClass"},
    {"Item": "Indoor Plant Growing Kit", "Example Vendor": "Click and Grow"},
    {"Item": "Guided Nature Hike", "Example Vendor": "REI Adventures"},
    {"Item": "Home Karaoke System", "Example Vendor": "Karaoke USA"},
    {"Item": "Astronomy Club Membership", "Example Vendor": "The Planetary Society"},
    {"Item": "Meditation App Subscription", "Example Vendor": "Headspace"},
    {"Item": "Origami Paper", "Example Vendor": "Aitoh"},
    {"Item": "Dart Board", "Example Vendor": "Winmau"},
    {"Item": "Air Hockey Table", "Example Vendor": "American Heritage"},
    {"Item": "RC Helicopter", "Example Vendor": "Syma"},
    {"Item": "Electric Scooter", "Example Vendor": "Segway"},
    {"Item": "Digital Sketch Pad", "Example Vendor": "Huion"},
    {"Item": "Action Camera", "Example Vendor": "GoPro"},
    {"Item": "Oil Painting Classes", "Example Vendor": "Local Art Studios"},
    {"Item": "DIY Robot Kit", "Example Vendor": "Lego Mindstorms"},
    {"Item": "Foil Fencing Classes", "Example Vendor": "USA Fencing"},
    {"Item": "Music Production Software", "Example Vendor": "Ableton Live"},
    {"Item": "Pool Table", "Example Vendor": "Brunswick Billiards"},
    {"Item": "Aquatic Fitness Classes", "Example Vendor": "YMCA"},
    {"Item": "Local Brewery Tour", "Example Vendor": "Samuel Adams"},
    {"Item": "Digital Comic Subscription", "Example Vendor": "ComiXology"},
    {"Item": "Foosball Table", "Example Vendor": "Tornado"},
    {"Item": "Calligraphy Set", "Example Vendor": "Speedball"},
    {"Item": "Poker Set", "Example Vendor": "Bicycle"},
    {"Item": "Mystery Novel Subscription", "Example Vendor": "Agatha Christie Ltd."},
    {"Item": "Bouldering Gym Pass", "Example Vendor": "The Cliffs"},
    {"Item": "Tarot Cards", "Example Vendor": "Rider-Waite"},
    {"Item": "Fantasy Football Subscription", "Example Vendor": "ESPN Fantasy Sports"},
    {"Item": "Planetarium Tickets", "Example Vendor": "Hayden Planetarium"},
    {"Item": "Chess Tutorial Software", "Example Vendor": "Chess.com"},
    {"Item": "Nature Photography Workshop", "Example Vendor": "National Geographic Expeditions"},
    {"Item": "Interactive Cooking Game", "Example Vendor": "Overcooked"},
    {"Item": "Sculpture Materials", "Example Vendor": "Sculpture House"},
    {"Item": "Frisbee Golf Set", "Example Vendor": "Innova Disc Golf"},
    {"Item": "Pottery Wheel", "Example Vendor": "Speedball"},
    {"Item": "Paddle Tennis Set", "Example Vendor": "Wilson"},
    {"Item": "Sudoku App Subscription", "Example Vendor": "Sudoku.com"},
    {"Item": "Ghost Tour Tickets", "Example Vendor": "Haunted History Tours"},
    {"Item": "Ballroom Dancing Shoes", "Example Vendor": "Capezio"},
    {"Item": "Home Escape Room Game", "Example Vendor": "Escape the Room"},
    {"Item": "Stargazing App", "Example Vendor": "Star Walk"},
    {"Item": "Cooking Magazine Subscription", "Example Vendor": "Bon Appetit"},
    {"Item": "Decorative Candle Making Kit", "Example Vendor": "CandleScience"},
    {"Item": "Travel Blogging Course", "Example Vendor": "Travel Blog Success"},
    {"Item": "Online Poker Platform", "Example Vendor": "PokerStars"},
    {"Item": "Table Tennis Set", "Example Vendor": "Butterfly"},
    {"Item": "Vegan Cooking Class", "Example Vendor": "Purple Carrot"}
]

# %%
# Creating a DataFrame
df_entertainment = pd.DataFrame(entertainment_items)
df_entertainment['Items'] = df_entertainment['Item'] + " " + df_entertainment['Example Vendor']
df_entertainment = df_entertainment.drop({'Item', 'Example Vendor'}, axis=1)
df_entertainment
# Out:
#                                           Items
# 0                    Movie Tickets AMC Theatres
# 1         Video Game Console Sony (PlayStation)
# 2        Streaming Service Subscription Netflix
# 3                            Board Games Hasbro
# 4                 E-Book Reader Amazon (Kindle)
# ..                                          ...
# 156  Decorative Candle Making Kit CandleScience
# 157  Travel Blogging Course Travel Blog Success
# 158            Online Poker Platform PokerStars
# 159                  Table Tennis Set Butterfly
# 160           Vegan Cooking Class Purple Carrot
#
# [161 rows x 1 columns]

# %%
df_entertainment.to_csv('entertainment_datebase.csv', index=0)

# %% [markdown]
# ---

# %%
grocery_items = [
    {"Item": "Whole Wheat Bread", "Example Vendor": "Dave's Killer Bread"},
    {"Item": "Organic Milk", "Example Vendor": "Horizon Organic"},
    {"Item": "Eggs", "Example Vendor": "Eggland's Best"},
    {"Item": "Almond Butter", "Example Vendor": "Justin's"},
    {"Item": "Greek Yogurt", "Example Vendor": "Chobani"},
    {"Item": "Extra Virgin Olive Oil", "Example Vendor": "Bertolli"},
    {"Item": "Quinoa", "Example Vendor": "Bob's Red Mill"},
    {"Item": "Frozen Vegetables", "Example Vendor": "Birds Eye"},
    {"Item": "Canned Tomatoes", "Example Vendor": "San Marzano"},
    {"Item": "Apple Cider Vinegar", "Example Vendor": "Bragg"},
    {"Item": "Honey", "Example Vendor": "Manuka Health"},
    {"Item": "Brown Rice", "Example Vendor": "Lundberg"},
    {"Item": "Pasta", "Example Vendor": "Barilla"},
    {"Item": "Coffee Beans", "Example Vendor": "Starbucks"},
    {"Item": "Green Tea", "Example Vendor": "Twinings"},
    {"Item": "Cereal", "Example Vendor": "Kellogg's"},
    {"Item": "Natural Peanut Butter", "Example Vendor": "Smucker's"},
    {"Item": "Dark Chocolate", "Example Vendor": "Lindt"},
    {"Item": "Sparkling Water", "Example Vendor": "LaCroix"},
    {"Item": "Almonds", "Example Vendor": "Blue Diamond"},
    {"Item": "Tofu", "Example Vendor": "Nasoya"},
    {"Item": "Canned Beans", "Example Vendor": "Goya"},
    {"Item": "Protein Bars", "Example Vendor": "Clif Bar"},
    {"Item": "Kale Chips", "Example Vendor": "Rhythm Superfoods"},
    {"Item": "Coconut Water", "Example Vendor": "Vita Coco"},
    {"Item": "Gluten-Free Bread", "Example Vendor": "Udi's"},
    {"Item": "Avocado Oil", "Example Vendor": "Chosen Foods"},
    {"Item": "Organic Chicken", "Example Vendor": "Bell & Evans"},
    {"Item": "Balsamic Vinegar", "Example Vendor": "Modena"},
    {"Item": "Granola", "Example Vendor": "Nature's Path"},
    {"Item": "Sweet Potatoes", "Example Vendor": "Organic Valley"},
    {"Item": "Frozen Pizza", "Example Vendor": "DiGiorno"},
    {"Item": "Orange Juice", "Example Vendor": "Tropicana"},
    {"Item": "Baby Spinach", "Example Vendor": "Earthbound Farm"},
    {"Item": "Cheddar Cheese", "Example Vendor": "Tillamook"},
    {"Item": "Dried Lentils", "Example Vendor": "Goya"},
    {"Item": "Salmon Fillets", "Example Vendor": "Wild Planet"},
    {"Item": "Almond Milk", "Example Vendor": "Silk"},
    {"Item": "Whole Grain Mustard", "Example Vendor": "Maille"},
    {"Item": "Soy Sauce", "Example Vendor": "Kikkoman"},
    {"Item": "Bottled Water", "Example Vendor": "Fiji"},
    {"Item": "Canned Tuna", "Example Vendor": "Bumble Bee"},
    {"Item": "Organic Apples", "Example Vendor": "Honeycrisp"},
    {"Item": "Olive Oil", "Example Vendor": "Pompeian"},
    {"Item": "Chia Seeds", "Example Vendor": "Nutiva"},
    {"Item": "Frozen Berries", "Example Vendor": "Dole"},
    {"Item": "Nutella", "Example Vendor": "Ferrero"},
    {"Item": "Sriracha Sauce", "Example Vendor": "Huy Fong Foods"},
    {"Item": "Ketchup", "Example Vendor": "Heinz"},
    {"Item": "Mayonnaise", "Example Vendor": "Hellmann's"},
    {"Item": "Flour Tortillas", "Example Vendor": "Mission"},
    {"Item": "Bacon", "Example Vendor": "Oscar Mayer"},
    {"Item": "Chicken Breast", "Example Vendor": "Tyson"},
    {"Item": "Sliced Turkey", "Example Vendor": "Boar's Head"},
    {"Item": "Ground Beef", "Example Vendor": "Certified Angus Beef"},
    {"Item": "Cornflakes", "Example Vendor": "Kellogg's"},
    {"Item": "Spaghetti", "Example Vendor": "De Cecco"},
    {"Item": "Russet Potatoes", "Example Vendor": "Idahoan"},
    {"Item": "Cream Cheese", "Example Vendor": "Philadelphia"},
    {"Item": "Rice Cakes", "Example Vendor": "Quaker"},
    {"Item": "Blueberries", "Example Vendor": "Driscoll's"},
    {"Item": "Romaine Lettuce", "Example Vendor": "Fresh Express"},
    {"Item": "Organic Carrots", "Example Vendor": "Bolthouse Farms"},
    {"Item": "Canned Soup", "Example Vendor": "Campbell's"},
    {"Item": "Oatmeal", "Example Vendor": "Quaker"},
    {"Item": "Gala Apples", "Example Vendor": "Washington Apple"},
    {"Item": "Lemonade", "Example Vendor": "Simply"},
    {"Item": "Tomato Sauce", "Example Vendor": "Hunt's"},
    {"Item": "Mozzarella Cheese", "Example Vendor": "Galbani"},
    {"Item": "Bagels", "Example Vendor": "Thomas'"},
    {"Item": "Butter", "Example Vendor": "Land O'Lakes"},
    {"Item": "Peanut Butter", "Example Vendor": "Jif"},
    {"Item": "Granulated Sugar", "Example Vendor": "Domino"},
    {"Item": "Chicken Noodle Soup", "Example Vendor": "Progresso"},
    {"Item": "Canned Corn", "Example Vendor": "Del Monte"},
    {"Item": "Strawberries", "Example Vendor": "California Giant"},
    {"Item": "White Rice", "Example Vendor": "Uncle Ben's"},
    {"Item": "Black Beans", "Example Vendor": "Bush's"},
    {"Item": "Whole Milk", "Example Vendor": "Organic Valley"},
    {"Item": "Ground Turkey", "Example Vendor": "Butterball"},
    {"Item": "Sliced Ham", "Example Vendor": "Hillshire Farm"},
    {"Item": "Canned Peas", "Example Vendor": "Green Giant"},
    {"Item": "Red Onions", "Example Vendor": "Vidalia"},
    {"Item": "Greek Olives", "Example Vendor": "Kalamata"},
    {"Item": "Sour Cream", "Example Vendor": "Daisy"},
    {"Item": "White Bread", "Example Vendor": "Wonder"},
    {"Item": "Orange Marmalade", "Example Vendor": "Smucker's"},
    {"Item": "Pickles", "Example Vendor": "Vlasic"},
    {"Item": "Salsa", "Example Vendor": "Pace"},
    {"Item": "Prosciutto", "Example Vendor": "Boar's Head"},
    {"Item": "Parmesan Cheese", "Example Vendor": "Kraft"},
    {"Item": "Bottled Smoothies", "Example Vendor": "Naked"},
    {"Item": "Raspberry Jam", "Example Vendor": "Bonne Maman"},
    {"Item": "Mixed Nuts", "Example Vendor": "Planters"},
    {"Item": "Frozen Waffles", "Example Vendor": "Eggo"},
    {"Item": "BBQ Sauce", "Example Vendor": "Sweet Baby Ray's"},
    {"Item": "Feta Cheese", "Example Vendor": "Athenos"},
    {"Item": "Canned Pineapple", "Example Vendor": "Dole"},
    {"Item": "Chocolate Syrup", "Example Vendor": "Hershey's"},
    {"Item": "Vegetable Oil", "Example Vendor": "Crisco"},
    {"Item": "Beef Jerky", "Example Vendor": "Jack Link's"},
    {"Item": "Pita Bread", "Example Vendor": "Joseph's"},
    {"Item": "Energy Drinks", "Example Vendor": "Red Bull"},
    {"Item": "Whole Grain Cereal", "Example Vendor": "Kashi"},
    {"Item": "Cottage Cheese", "Example Vendor": "Breakstone's"},
    {"Item": "Maple Syrup", "Example Vendor": "Aunt Jemima"},
    {"Item": "Balsamic Glaze", "Example Vendor": "Nonna Pia's"},
    {"Item": "Seaweed Snacks", "Example Vendor": "gimMe"},
    {"Item": "Hazelnut Spread", "Example Vendor": "Nutella"},
    {"Item": "Vegan Cheese", "Example Vendor": "Daiya"},
    {"Item": "Sushi Rice", "Example Vendor": "Nishiki"},
    {"Item": "Dijon Mustard", "Example Vendor": "Grey Poupon"},
    {"Item": "Rice Noodles", "Example Vendor": "A Taste of Thai"},
    {"Item": "Quinoa Pasta", "Example Vendor": "Ancient Harvest"},
    {"Item": "Spelt Flour", "Example Vendor": "Bob's Red Mill"},
    {"Item": "Almond Flour", "Example Vendor": "King Arthur"},
    {"Item": "Coconut Flour", "Example Vendor": "Viva Naturals"},
    {"Item": "Black Tea", "Example Vendor": "Lipton"},
    {"Item": "Herbal Tea", "Example Vendor": "Celestial Seasonings"},
    {"Item": "Agave Syrup", "Example Vendor": "Wholesome"},
    {"Item": "Stevia Sweetener", "Example Vendor": "Truvia"},
    {"Item": "Brown Sugar", "Example Vendor": "Domino"},
    {"Item": "Powdered Sugar", "Example Vendor": "C&H"},
    {"Item": "Sea Salt", "Example Vendor": "Maldon"},
    {"Item": "Black Pepper", "Example Vendor": "McCormick"},
    {"Item": "Turmeric", "Example Vendor": "Simply Organic"},
    {"Item": "Cumin", "Example Vendor": "McCormick"},
    {"Item": "Paprika", "Example Vendor": "McCormick"},
    {"Item": "Oregano", "Example Vendor": "McCormick"},
    {"Item": "Basil", "Example Vendor": "McCormick"},
    {"Item": "Cinnamon", "Example Vendor": "McCormick"},
    {"Item": "Vanilla Extract", "Example Vendor": "McCormick"},
    {"Item": "Cocoa Powder", "Example Vendor": "Hershey's"},
    {"Item": "Baking Powder", "Example Vendor": "Clabber Girl"},
    {"Item": "Baking Soda", "Example Vendor": "Arm & Hammer"},
    {"Item": "Yeast", "Example Vendor": "Fleischmann's"},
    {"Item": "Cornstarch", "Example Vendor": "Argo"},
    {"Item": "Peanut Oil", "Example Vendor": "LouAna"},
    {"Item": "Canola Oil", "Example Vendor": "Wesson"},
    {"Item": "Olive Oil Spray", "Example Vendor": "PAM"},
    {"Item": "Balsamic Vinaigrette", "Example Vendor": "Kraft"},
    {"Item": "Ranch Dressing", "Example Vendor": "Hidden Valley"},
    {"Item": "Caesar Dressing", "Example Vendor": "Ken's"},
    {"Item": "Italian Dressing", "Example Vendor": "Wish-Bone"},
    {"Item": "Soy Milk", "Example Vendor": "Silk"},
    {"Item": "Rice Milk", "Example Vendor": "Rice Dream"},
    {"Item": "Oat Milk", "Example Vendor": "Oatly"},
    {"Item": "Chicken Broth", "Example Vendor": "Swanson"},
    {"Item": "Beef Broth", "Example Vendor": "Knorr"},
    {"Item": "Vegetable Broth", "Example Vendor": "Pacific Foods"},
    {"Item": "Apple Juice", "Example Vendor": "Mott's"},
    {"Item": "Grape Juice", "Example Vendor": "Welch's"},
    {"Item": "Cranberry Juice", "Example Vendor": "Ocean Spray"},
    {"Item": "Tomato Juice", "Example Vendor": "V8"},
    {"Item": "Sports Drink", "Example Vendor": "Gatorade"}
]

# %%
df_grocery = pd.DataFrame(grocery_items)
# Assuming df_home_garden is your DataFrame
df_grocery['Items'] = df_grocery['Item'] + " " + df_grocery['Example Vendor']

# Dropping the columns 'Item' and 'Example Vendor'
df_grocery = df_grocery.drop(['Item', 'Example Vendor'], axis=1)

# Applying pd.unique() to the 'new' column of the DataFrame
unique_values = pd.unique(df_grocery['Items'])
len(unique_values)
# Out:
# 155

# %%
df_grocery = pd.DataFrame(unique_values, columns=['Items'])
df_grocery
# Out:
#                                      Items
# 0    Whole Wheat Bread Dave's Killer Bread
# 1             Organic Milk Horizon Organic
# 2                      Eggs Eggland's Best
# 3                   Almond Butter Justin's
# 4                     Greek Yogurt Chobani
# ..                                     ...
# 150                     Apple Juice Mott's
# 151                    Grape Juice Welch's
# 152            Cranberry Juice Ocean Spray
# 153                        Tomato Juice V8
# 154                  Sports Drink Gatorade
#
# [155 rows x 1 columns]

# %%
df_grocery.to_csv('grocery_datebase.csv', index=0)

# %% [markdown]
# ##  Data Classification

# %%
import pandas as pd

clothing_df = pd.read_csv('./categorized test/categorized_clothing_database.csv')
electronics_df = pd.read_csv('./categorized test/categorized_electronics_database.csv')
entertainment_df = pd.read_csv('./categorized test/categorized_entertainment_database.csv')
food_service_df = pd.read_csv('./categorized test/categorized_food_service_database.csv')
grocery_df = pd.read_csv('./categorized test/categorized_grocery_database.csv')
health_beauty_df = pd.read_csv('./categorized test/categorized_health_beauty_database.csv')
home_garden_df = pd.read_csv('./categorized test/categorized_home_garden_database.csv')

# %% [markdown]
# ## receipts import

# %%
import json

# Read and parse the JSON file
with open('./entities.json', 'r') as file:
    data = json.load(file)

# %%
# Initialize variables
entry_number = 0
current_merchant = None

# Initialize a list to store the processed entries as dictionaries
processed_entries = []

# Iterate through the data
for entry in data:
    entry_number += 1  # Increment the entry number
    merchant = entry["ReceiptInfo"]["merchant"]
    items = entry["ReceiptInfo"]["ITEMS"]
    
    # Remove "number+space" occurrences in the descriptions and combine them
    cleaned_descriptions = []
    for item in items:
        description = item.get('description', 'No Description')
        cleaned_description = ' '.join(word for word in description.split() if not word.isdigit())
        cleaned_descriptions.append(cleaned_description)
    
    # Combine descriptions with spaces
    combined_descriptions = ' '.join(cleaned_descriptions)
    
    # Remove "UNKNOWN," "<UNKNOWN>," and "unknown" from the merchant field
    merchant = merchant.replace("UNKNOWN", "").replace("<UNKNOWN>", "").replace("unknown", "").replace("<>", "")
    
    # Remove "UNKNOWN," "<UNKNOWN>," and "unknown" from the combined_descriptions field
    combined_descriptions = combined_descriptions.replace("UNKNOWN", "").replace("<UNKNOWN>", "").replace("unknown", "").replace("<>", "")
    
    # Create a dictionary for the current entry
    entry_dict = {
        "entry_number": entry_number,
        "merchant": merchant,
        "combined_descriptions": combined_descriptions
    }
    
    # Append the dictionary to the list
    processed_entries.append(entry_dict)

# Display the processed entries as dictionaries
for entry in processed_entries:
    print(entry)
# Out:
# {'entry_number': 1, 'merchant': 'Halal Gyro Kabob House', 'combined_descriptions': '#18. Lamb Salad'}
# {'entry_number': 2, 'merchant': 'WHOLE FOODS MARKET', 'combined_descriptions': '365WFM OG ITALIAN BAG 365WFM BREADED CALAMARI OG RSTD PEANUT BUTTER OVF OG UHT WHOLE MLK 365WFM PECAN HALVES'}
# {'entry_number': 3, 'merchant': 'LEAHI HEALTH MANOA', 'combined_descriptions': '5. Deep Green'}
# {'entry_number': 4, 'merchant': 'Longs Drugs', 'combined_descriptions': 'OREO ORIG DBL STFF 14.0 BAUD WAFER CHOCLT HWNISL TEABG GVGNS'}
# {'entry_number': 5, 'merchant': 'Kozo Sushi', 'combined_descriptions': 'Cucumber Maki Shrimp Tempura Hr'}
# {'entry_number': 6, 'merchant': "McDonald's Restaurant #14616", 'combined_descriptions': 'Happy Meal Ch Burger Cheeseburger Extra Kids Fry Apple Juice S Apl Jc Surcharge ELEMENTAL S Grimace Bday Shake S Shake Surcharge'}
# ...

# %%
merchants = []
descriptions = []

for entry in processed_entries:
    merchant = entry["merchant"]
    description = entry["combined_descriptions"]
    merchants.append(merchant)
    descriptions.append(description)

# %%
len(merchants)
# Out:
# 14

# %%
entities_df = pd.DataFrame({
    'Merchants': merchants, 
    'Descriptions': descriptions
})
entities_df
# Out:
#                        Merchants  \
# 0         Halal Gyro Kabob House
# 1             WHOLE FOODS MARKET
# 2             LEAHI HEALTH MANOA
# 3                    Longs Drugs
# 4                     Kozo Sushi
# 5   McDonald's Restaurant #14616
# 6                    Longs Drugs
# 7                         H MART
# 8                          Longs
# 9                     Sam's Club
# 10                       Walmart
# 11           Panda Express #2150
# 12                        H Mart
# 13                 See's Candies
#
#                                          Descriptions
# 0                                     #18. Lamb Salad
# 1   365WFM OG ITALIAN BAG 365WFM BREADED CALAMARI ...
# 2                                       5. Deep Green
# 3   OREO ORIG DBL STFF 14.0 BAUD WAFER CHOCLT HWNI...
# 4                     Cucumber Maki Shrimp Tempura Hr
# 5   Happy Meal Ch Burger Cheeseburger Extra Kids F...
# 6   CFRIO SF PEG BAG 3Z 4.59B CFRIO SF PEG BAG 3Z ...
# ...

# %%
entities_df.to_csv('entities_database.csv', index=0)

# %% [markdown]
# ## str items to List

# %%
import pandas as pd

def create_multicolumn_dataframe(**kwargs):
    # Split each string into a list
    columns = [re.split(r', | - ', value) for value in kwargs.values()]

    # Find the length of the longest list
    max_length = max(len(column) for column in columns)

    # Pad shorter lists with None
    padded_columns = [column + [None] * (max_length - len(column)) for column in columns]

    # Transpose the list of lists to align items as columns
    transposed_columns = list(zip(*padded_columns))

    # Create a DataFrame
    df = pd.DataFrame(transposed_columns, columns=kwargs.keys())
    
    return df

def create_single_column_dataframe(**kwargs):
    # Split each string into a list
    columns = [value.split(", ") for value in kwargs.values()]

    # Find the length of the longest list
    max_length = max(len(column) for column in columns)

    # Pad shorter lists with None
    padded_columns = [column + [None] * (max_length - len(column)) for column in columns]

    # Transpose the list of lists to align items as columns
    transposed_columns = list(zip(*padded_columns))

    # Create a DataFrame
    df = pd.DataFrame(transposed_columns, columns=kwargs.keys())
    
    # Melt the DataFrame to combine all columns into one
    df_melted = df.melt(var_name='Column', value_name='Item').drop('Column', axis=1).dropna().reset_index(drop=True)
    
    return df_melted

# %% [markdown]
# # Groceries

# %% [markdown]
# ### Fruits

# %%
a = "Apples, Açaí, Acerola Cherries, African Breadfruit, Akebi Fruit, Alpine Strawberry, African Mango, Amanatsu Oranges, Ambarella, Amaou Strawberries, Ambrosia Apples, Ambrosia Melon, Amla, Apricots, Annatto, Annona, Asian Pears, Arava Melon, Asam Kumbang, Avocado"
b = "Babaco, Bacuri Fruit, Balsam Apples, Barbados Cherries, Barberries, Batuan, Beach Plums, Bearberries, Beechnut, Bell Peppers, Betel Nut, Bilberries, Biriba, Bitter Melon, Black Apples, Blackberries, Black Cherries, Black Currant, Black Mulberry, Black Raspberries, Black Sapote, Blood Lime, Blood Orange, Blue Dragon Fruit, Blue Java Banana, Blue Marble Fruit, Blue Olive, Blue Pearmain Apple, Blue Sausage Fruit, Blue Watermelon, Blueberries, Bottle Gourd, Boysenberry, Brazilian Guava, Brazil Nut, Breadfruit, Brush Cherry"
c = "Cabernet Sauvignon Grape, Calabash, Camu Camu Berry, Canary Fruit, Canistel Fruit, Cantaloupe, Caper Berry, Carambola, Carob, Cavendish Banana, Cedar Bay Cherry, Cempedak, Cherry, Chinese Quince, Chinese White Pear, Chinoto Sour Orange, Churchland Pear, Citron, Clementine, Cleopatra Mandarin, Coconut, Coco plum, Conference Pear, Cornelian Cherry, Cortland Apple, Cosmic Crisp Apple, Courgette, Crab Apple, Cranberry, Crimson Delight Apple, Crimson Gold Apple, Crispin Apple, Cucumber, Custard Apple"
d = "Dabai Fruit, Dangle Berry, Damson Plums, Darling Plum, Darwin’s Barberries, Date Plums, Davidson’s Plums, Dates, Dead Man’s Finger, Dekopon, Dessert Banana, Desert Fig, Desert Lime, Desert Quandong, Dewberries, Dinosaur Eggs, Discovery Apple, Dodder Laurel, Double Coconut, Dracontomelon, Dragon Fruit, Duku Fruit, Durian"
e = "Emu Berry Fruit, Enterprise Apple, Evergreen Huckleberry, Eggplant, Elephant Apple (Chalta), Etrog, Elderberry, Emu Apple Fruit, Emblica, European Pear, Eastern Hawthorn Fruit, Egg Fruit, Early Gold Mango, Entawak, Elands Sour Fig, Ensete, Early Girl Tomato"
f = "Fairchild Tangerines, False Mastic Fruit, Farkleberry, Fascell Mango, Fazli Mango, Feijoa, Fe’I Banana, Fibrous Satinash Fruit, Figs, Finger Lime, Five Flavor Berry, Flatwoods Plum, Florida Cherry, Forest Strawberries, Fox Grapes, Fuji Apples, Fukushu Kumquat"
g = "Gala Apple, Galia Melon, Gamboge, Genip, Giant Lau Lau, Goji Berry, Golden Apple, Golden Delicious Apple, Golden Kiwi, Gooseberry, Gorham Pear, Goumi, Governor’s Plum, Granadilla, Grand Nain Banana, Granny Smith Apple, Grapefruit, Grape, Greek Fig, Green Adjou Pear, Green Apple, Green Banana, Green Bell Pepper, Green Egg Squash, Green Fig, Green Gage Plum, Green Grapes, Green Lemon, Green Raisins, Green Strawberry, Green Tomato, Ground Plum, Grosella Negra, Grumichama, Guarana, Guava, Guavaberry"
h = "Hackberry, Hala Fruit, Hardy Kiwi, Hawaiian Mountain Apples, Hawthorn Fruit, Hazelnuts, Heirloom Tomatoes, Highbush Blueberries, Highbush Cranberries, Himalayan Mulberries, Hog Plums, Honeyberries, Honey Crisp Apples, Honeydew Melon, Honey Locust, Honeysuckles, Horned Melon, Huckleberry, Huito, Husk Tomatoes, Hyuganatsu"
i = "Imbe, Icacina, Iboga, Icaco, Indian Jujube Fruit, Indian Prune, Indian Sherbet Berry, Ice Apple, Indonesian Lime, Ilama, Ita Palm Fruit, Indian Almond Fruit, Imbu, Incaberry, Ice Cream Bean Fruit, Ichigo, Illawarra Plum, Indian Gooseberry, Indian Persimmon"
j = "Jackfruit, Jamun Plum, Japanese Persimmon, Japanese Plum, Jatoba, Java Apple, Jazz Apples, Jelly Palm Fruit, Johannisbeere, Jostaberry, Juicy Tomatoes, Jujube Fruit, Junglesop Fruit, Juniper Berries"
k = "Kabosu, Kaffir Lime, Kahikatea, Kakadu Plum, Kaki Persimmon, Kanzi Apple, Karonda Berry, Kasturi Mango, Kawakawa, Kaywa, Kei Apple, Keitt Mango, Key Lime, Kiwano, Kiwi, Knobby Russet Apple, Korean Pear, Korlan, Kowai, Kumquats, Kutjera Fruit, Kvede, Kwai Muk, Kyoho Grape"
l = "Lablab Fruit, Lady Apple, Lady Finger Banana, Lambkin Melon, Lancetilla Mango, Langra Mango, Langsat, Lapsi, Le Conte Pear, Lemato, Lemon Aspen, Lemon Drop Melon, Lemon, Liberty Apple, Lilly Pilly, Lima Orange, Limau Bali, Lime, Limeberry, Limquat, Lingonberry, Lippens Mango, Lodi Apple, Loganberry, Long Neck Avocado, Lord Lambourne Apple, Loquat, Louise Bonne of Jersey Pear, Lucuma"
m = "Macadamia Nut, Macoun Apple, Madison Peach, Madrono, Mamey Sapote, Mammee Apple, Mamoncillo, Mandarin, Mangaba, Mango, Mangosteen, Maqui, Maracuya, Marang, Margil Apples, Marionberry, Marisol Clementine, Marsh Pink Grapefruit, Marula, May Apple, May Pride Peaches, Mayan Nut, Maypop, McIntosh Apple, Melon Pear Fruit, Merlot Grape, Meyer Lemon, Mexican Lime, Mexican Limes, Midyim Berry, Minneolo Tangelo, Miracle Fruit, Mock Strawberry, Monster Deliciosa"
n = "Naartjie, Nagami Kumquat, Nageia, Nam Dok Mai, Nance, Naranjilla, Narenj, Natal Plum, Nashi Pears, Naval Oranges, Nectacot, Nectacotum, Nectarines, Neem, Nepali Hog Plums, Nere Fruit, Newton Pippin Apple, Nocera Grape, Nopal Fruit, Northern Spy Apples, Nungu Fruit, Nutmeg, Nuts"
o = "O’Henry Peach, Oeillade Noire Grape, Ogallala Strawberry, Ogeechee Lime, Oil Palm, Okra, Okuzgozu Grape, Olallieberry, Olive, Opal Apple, Opal Plum, Opuntia, Orange, Orangelo, Oregon Grape, Orient Melon, Orient Pear, Oriental Cherry, Orin Apple, Orlando Tangelo, Oroblanco, Ortanique, OSO Grande Strawberry, Osteen Mango, Otaheite Gooseberry, Oullins Gage Plum, Oval Kumquat, Ozark Beauty Strawberry, Ozark Gold Apple"
p = "Pacific Rose Apple, Palestinian Sweet Limes, Papaya, Parsonage Pears, Passion Fruit, Paw Paw, Peaches, Peach Palm Fruit, Pears, Pecan, Pequi Fruit, Persian Limes, Persimmons, Petit Rouge Grapes, Peumo Fruit, Pie Pumpkins, Pigeon Plum, Pigface Fruit, Pili Fruit, Pineapple, Pineberries, Pink Lady Apples, Pink Pearl Apples, Pink Pineapple, Pink Pomelo, Pinot Noir Grapes, Pinova Apples, Pitaya, Plantains, Plums, Plumcots, Pluots, Pomato, Pomegranate, Pomelo, Ponderosa Lemons, Prickly Pears, Prunes, Pumpkins"
q = "Quince, Quandong, Quararibea, Querina Apples, Quinault Strawberry, Queen Anne Cherry, Queen Apple, Queen’s Forelle Pear, Queen Tahiti Pineapple"
r = "Raisins, Rajka Apples, Rambai, Rambutan, Ramontchi, Rangpur Lime, Raspberry, Raspuri Mango, Rata, Red Banana, Red Bayberry, Red Delicious Apple, Red Grape, Red Huckleberry"
s = "Sand Cherry, Saigon Mango, Salak, Santol, Satsuma Mandarin, Serviceberry, Shonan Gold, Sloe, Soncoya, Sour Cherry, Sour Plum, Soursop, Splendor Apple, Star Apple, Star Fruit, Strawberry, Strawberry Guava, Sudachi, Sugar Baby Watermelon, Sugar Berry, Sugar Plum, Sunset Apple, Sweet Granadilla, Sweet Lime"
t = "Tamarillo, Tamarind, Tangelo, Tangerine, Tangor, Tara Vine, Tarocco Orange, Tayberry, Tejocote, Terap, Texas Persimmon, Thai Lime, Thimbleberry, Thomcord Grape, Thompson Seedless Grape, Thorn Melon, Thornapple, Threeleaf Goldthread, Tiger Nut, Tomato, Tomatillo, Topaz Apple, Totapuri Mango, Toyon Berry, Trabzon Persimmon, Tree Tomato, Triphal, Tropical Almond, Truffle Berry, Tsunami Apple, Tucuma, Tulip Tree Fruit, Turkish Fig, Turtle Berry, Tutti Frutti"
u = "Ububese, Ugli Fruit, Ugni Berry, Umbu Fruit, Umbra Fruit, Urava Fruit, Usuma Fruit, Umeboshi, Uvilla Fruit"
v = "Vaccarese Grapes, Valencia Oranges, Valencia Pride Mango, Van Dyke Mango, Vanilla, Velvet Apple, Velvet Tamarind, Vespolina Grape, Vicar of Winkfield Pear, Victoria Plum, Villafranca Lemon, Voavanga Fruit, Volkamer Lemon"
w = "Wahoo, Walnut, Wampee, Water Apple, Water Chestnut, Watermelon, Wax Apple, Wax Gourd, Wealthy Apple, West Indian Cherry, Western Hackberry, White Aspen, White Currant, White-Flowered Gourd, White Mulberries, Wild Bacher Grape, Wild Banana, Custard Apple, Wild Lemon, Wild Lowbush Blueberry, Wild Mangosteen, Wild Orange, Wild Peach, Wild Strawberry, Wild Sugar Apple, Wild Water Lemon, Williams Pear, Winter Melon, Winter Squash, Wolf Berry"
x = "Xanthium Strumarium, Xarel-lo, Xerophyte, Xigua fruit, Ximenia Americana, Ximenia Caffra, Xinomavro, Xoconostle Cactus Fruit, Xylocarp"
y = "Ya Pear, Yali Pear, Yangmei, Yayat, Yellow Bell Peppers, Yellow Chili Pepper, Yellow Dragon Fruit, Yayat Palm, Yellow Apple, Yellow Guava, Yellow Passion Fruit, Yellow Plum, Yellow Sapote, Yellow Strawberry, Yellow Watermelon, Yemenite Citron, York Apple, Young Mango, Youngberry, Yucca, Yumberry, Yunnan Hackberry, Yuzu"
z = "Zabergau Reinette Apple, Zalzalak, Zante Currant, Zarzamora, Zawngtah, Zebra Melon, Zestar Apple, Zhe, Zierfandler Grape, Zig Zag Vine Fruit, Zill Mango, Zinfandel Grape, Ziziphus Mauritiana, Zucchini, Zweigelt Grape"

# %%
fruits_df = create_multicolumn_dataframe(a=a, b=b, c=c, d=d, e=e, f=f, g=g, h=h, i=i, j=j, k=k, l=l, m=m, n=n, o=o, p=p, q=q, r=r, s=s, t=t, u=u, v=v, w=w, x=x, y=y, z=z)
fruits_df = create_single_column_dataframe(a=a, b=b, c=c, d=d, e=e, f=f, g=g, h=h, i=i, j=j, k=k, l=l, m=m, n=n, o=o, p=p, q=q, r=r, s=s, t=t, u=u, v=v, w=w, x=x, y=y, z=z)
fruits_df

path = './product database/Groceries/fruits_database.csv'
fruits_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
# Out:
#                     Item
# 0                 Apples
# 1                   Açaí
# 2       Acerola Cherries
# 3     African Breadfruit
# 4            Akebi Fruit
# ..                   ...
# 593           Zill Mango
# 594      Zinfandel Grape
# 595  Ziziphus Mauritiana
# 596             Zucchini
# 597       Zweigelt Grape
#
# [598 rows x 1 columns]

# %% [markdown]
# ### Vegetables

# %%
a = "Acorn Squash, Alfalfa Sprouts, All Blue Potato, Amaranth, Ambercup Squash, Anise, Artichoke, Arugula, Ash Gourd, Asparagus, Avocado, Adzuki Bean, Ahipa, Aonori, Arame, Arikara Squash, Arrowroot, Asian Greens, Azuki Bean, Baby Boo Pumpkin, Bamboo Shoot, Banana Pepper, Banana Squash, Basil, Bean Sprout, Beet, Belgian Endive, Bell Pepper, Bintje Potato, Bitter Melon, Black Bean, Black-Eyed Pea, Black Radish, Black Salsify, Bok Choy, Boniato, Borage, Borlotti Bean, Boston Morrow Squash, Broad Beans, Broad-Leaf Arrowhead, Broccoflower, Broccoli, Broccolini, Brussels Sprout, Burdock Root, Butterhead Lettuce, Butter Bean, Butternut Squash, Cabbage, Cannellini Bean, Caraway, Carnival Squash, Carrot, Cauliflower, Cayenne Pepper, Celeriac, Celery, Chamomile, Chard, Cheddar Cauliflower, Cherry Pepper, Chickpeas, Chili Pepper, Chives, Collard Greens, Coriander, Corms, Corn, Cucumber, Daikon, Delicata, Dickinson Pumpkin, Dill, Eddoe, Eggplant, Endive, Fat Hen, Fava Bean, Fayot Bean, Fennel, Fiddlehead, Field Cucumber, Fiorentino Tomato, Flat Beans, Flat Italian Onion, Flat White Boer Pumpkin, Flint Corn, Fluted Pumpkin, French Bean, French Sorrel, Frisée, Futsu Squash, Garlic, Gem Squash, German Butterball Potato, Gigante Bean, Ginger, Gold rush Squash, Great Northern Bean, Green Bean, Habanero Pepper, Honey Bear Squash, Honeynut Squash, Hot Pepper, Hubbard Squash, Jalapeño, Japanese Sweet Potato, Jerusalem Artichoke, Jicama, Kale, Kelp, Kidney Bean, Kohlrabi, Konjac, Lavender, Leek, Lentil, Lettuce, Lima bean, Lumina Pumpkin, Malanga, Mallow, Mangelwurzel, Mangetout, Marjoram, Miner’s Lettuce, Molokhia, Morels, Mung Bean, Mushroom, Mustard Greens, Navy Bean, Nettle, New Potato, New Zealand Spinach, Oak Leaf Lettuce, Okra, Onion, Orange Bell Pepper, Orange Tomato, Oregano, Paprika, Parsnip, Pattypan Squash, Pea, Peanut, Pepper, Peruvian Purple Potato, Pie Pumpkin, Pinto Bean, Potato, Purple Asparagus, Purple Bell Pepper, Purple Brussels Sprout, Purple Cabbage, Purple Carrot, Purple Cauliflower, Purple Corn, Purple Kale, Purple Lettuce, Purple Majesty Potato, Purple Radish, Purple String Bean, Purple Tomato, Radicchio, Radish, Red Bell Pepper, Red Bliss Potato, Red Cabbage, Red Carrot, Red Gold Potato, Red Kuri Squash, Red Onion, Red Russian Kale, Red Warty Thing Squash, Red Wing Onion, Rhubarb, Rosemary, Runner Bean, Russian Banana Potato, Rutabaga, Salsify, Savoy Cabbage, Scallion, Shallot, Skirret, Snap Pea, Soybean, Spaghetti Squash, Spinach, Split Pea, Squash, Stokes Purple Sweet Potato, Sweet Corn, Sweet Potato, Tabasco Pepper, Taro, Tat Soi, Thyme, Tomatillo, Tomato, Topinambur, Torpedo Onion, Turnip, Ube, Udupi Mattu Gulla Eggplant, Ulluco, Upland Cress, Urad Bean, Velvet Bean, Vidalia Onion, Vivaldi Potato, Vitelotte Potato, Wasabi, Water Chestnut, Watercress, Wax Bean, White Pot Pepper, White Asparagus, White Bell Pepper, White Corn, Xi Lan Hua, Xi Yang Ca, Xà Lách, Xanthosoma Sagittifolium, Xanthosoma Brasiliense, Yam, Yellow Onion, Yellow Summer Squash, Yellow Tomato, Yukon Gold Potato, Zephyr Squash, Zucchini"

# %%
vegetables_df = create_multicolumn_dataframe(a=a)
vegetables_df = create_single_column_dataframe(a=a)
vegetables_df

path = './product database/Groceries/vegetables_database.csv'
vegetables_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
# Out:
#                      Item
# 0            Acorn Squash
# 1         Alfalfa Sprouts
# 2         All Blue Potato
# 3                Amaranth
# 4         Ambercup Squash
# ..                    ...
# 229  Yellow Summer Squash
# 230         Yellow Tomato
# 231     Yukon Gold Potato
# 232         Zephyr Squash
# 233              Zucchini
#
# [234 rows x 1 columns]

# %% [markdown]
# ### Meats

# %%
a = "Beef, Ribeye Steak, Certified Angus Beef, Filet Mignon, Omaha Steaks, Ground Beef, Tyson Foods, T-Bone Steak, Kansas City Steak Company, Chuck Roast, Hormel, Sirloin Steak, Swift, Brisket, Snake River Farms, Corned Beef, Libby's, Beef Ribs, Creekstone Farms, Beef Jerky, Jack Link's, Chicken, Chicken Breast, Perdue, Chicken Thighs, Foster Farms, Chicken Wings, Pilgrim's Pridea, Whole Chicken, Tyson Foods, Chicken Drumsticks, Sanderson Farms, Chicken Nuggets, Bell & Evans, Rotisserie Chicken, Costco, Ground Chicken, Butterball, Chicken Sausage, Aidells, Chicken Tenders, Springer Mountain Farms, Pork, Bacon, Oscar Mayer, Pork Chops, Smithfield, Ham, HoneyBaked Ham, Pork Belly, Farmland, Sausage, Johnsonville, Pork Loin, Hatfield, Ribs, Baby Back Ribs, St. Louis Ribs, Ground Pork, Jimmy Dean, Pork Tenderloin, Hormel, Prosciutto, Boar's Head, Seafood, Salmon, Wild Planet, Shrimp, SeaPak, Tuna, Bumble Bee Seafoods, Cod, Gorton's, Lobster, Maine Lobster Now, Crab, Phillips Foods, Halibut, High Liner Foods, Scallops, Sea Best, Sardines, King Oscar, Trout, Clear Springs Foods, Turkey, Turkey Breast, Butterball, Ground Turkey, Jennie-O, Turkey Bacon, Applegate, Whole Turkey, Norbest, Turkey Sausage, Hillshire Farm, Turkey Burgers, Shady Brook Farms, Turkey Deli Meat, Boar's Head, Smoked Turkey, Honeysuckle White, Turkey Drumsticks, Perdue, Turkey Jerky, Wild Turkey, Lamb, Lamb Chops, Superior Farms, Ground Lamb, American Lamb, Lamb Shank, New Zealand Spring Lamb, Lamb Ribs, Halal Pastures, Lamb Leg, Strauss Brands, Lamb Sausage, Merguez, Rack of Lamb, Thomas Foods, Lamb Shoulder, Shepherd Song Farm, Lamb Stew Meat, D'Artagnan, Lamb Burgers, Cedar Springs, Other Meats, Venison, Steaks and Game, Duck Breast, Maple Leaf Farms, Bison, North American Bison, Rabbit, D'Artagnan, Quail, Manchester Farms, Goose, Schiltz Foods, Wild Boar, Broken Arrow Ranch, Pheasant, MacFarlane Pheasants, Ostrich, Blackwing Ostrich, Kangaroo, Exotic Meat Market, Deli Meats, Pastrami, Dietz & Watson, Salami, Columbus Craft Meats, Pepperoni, Hormel, Roast Beef, Thumann's, Bologna, Oscar Mayer, Corned Beef, Vienna Beef, Mortadella, Fiorucci, Prosciutto, Principe, Capicola, Volpi Foods, Soppressata, Creminelli, Exotic Meats, Alligator, Cajun Grocer, Frog Legs, Gourmet Food Store, Snail, Escal, Emu, Amaroo Hills, Crocodile, Exotic Meat Market, Bear, Mountain America Jerky, Camel, Fossil Farms, Elk, Blackwing Meats, Rattlesnake, Exotic Meat Market, Python, Exotic Meat Market, Sausages and Processed Meats, Chorizo, Palacios, Andouille, Aidells, Bratwurst, Johnsonville, Kielbasa, Hillshire Farm, Italian Sausage, Premio Foods, Blood Sausage, Morcilla, Wieners, Nathan's Famous, Frankfurters, Sabrett, Liverwurst, Boar's Head, Hot Dogs, Ball Park, Specialty and Cured Meats, Jamón Ibérico, Cinco Jotas, Guanciale, La Quercia, Serrano Ham, Fermin, Lardo, Il Porcellino, Speck, Alto Adige, Bresaola, Bernina, Pancetta, Citterio, Cotechino, Veroni, Culatello, Zibello, Lomo Embuchado, Palacios, Game Birds and Poultry, Pheasant, D'Artagnan, Partridge, Wild Scottish Game, Grouse, Yorkshire Game, Squab, Palmetto Pigeon Plant, Guinea Fowl, Joyce Farms, Teal, Wild Game, Wood Pigeon, Game-to-Eat, Ptarmigan, Arctic Game, Snipe, Wild Bird Game, Quail Eggs, Manchester Farms, Offal and Variety Meats, Beef Liver, US Wellness Meats, Chicken Hearts, Foster Farms, Pork Kidneys, Smithfield, Sweetbreads, Heritage Foods, Tripe, Menudo, Beef Tongue, Lone Mountain Wagyu, Chicken Gizzards, Tyson, Pork Hocks, Niman Ranch, Lamb Brains, Halal Pastures, Oxtail, Rumba Meats, Specialty Prepared Meats, Beef Wellington, D'Artagnan, Coq au Vin, Williams Sonoma, Porchetta, Belcampo, Beef Bourguignon, Omaha Steaks, Chicken Cordon Bleu, Barber Foods, Duck à l'Orange, Maple Leaf Farms, Rack of Lamb, Crown Roast, Stuffed Chicken Breast, Perdue, Meatloaf, Boston Market, Pork Crown Roast, Snake River Farms, Canned and Packaged Meats, Spam, Hormel, Vienna Sausage, Libby's, Corned Beef Hash, Mary Kitchen, Potted Meat, Armour, Sardines in Oil, King Oscar, Anchovies, Roland, Canned Chicken, Swanson, Canned Tuna, StarKist, Canned Salmon, Redhead, Deviled Ham, Underwood"

# %%
meats_df = create_multicolumn_dataframe(a=a)
meats_df = create_single_column_dataframe(a=a)
meats_df

path = './product database/Groceries/meats_database.csv'
meats_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
# Out:
#                      Item
# 0                    Beef
# 1            Ribeye Steak
# 2    Certified Angus Beef
# 3            Filet Mignon
# 4            Omaha Steaks
# ..                    ...
# 311              StarKist
# 312         Canned Salmon
# 313               Redhead
# 314           Deviled Ham
# 315             Underwood
#
# [316 rows x 1 columns]

# %% [markdown]
# ### Dairy

# %%
path = './product database/Groceries/dairy_database.csv'
df = pd.read_csv(path, encoding='ISO-8859-1')
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
# Out:
#                   Item
# 0                Aarts
# 1         Acidophiline
# 2                Amasi
# 3                Ayran
# 4              Basundi
# ..                 ...
# 252       Winder Farms
# 253  Winter Park Dairy
# 254  Wawa Food Markets
# 255         Yakult USA
# 256     Yancey's Fancy
#
# [251 rows x 1 columns]

# %% [markdown]
# ### dry_goods_database

# %%
a ="Pasta, Rice, Gnocchi, Ramen noodles, Quinoa, Farro, Couscous, Barley, Dried beans, Lentils, Millet, Flours, Cornmeal, Breadcrumbs, Breakfast cereal, Oats, Granola, Dried herbs and spices, Baking powder, Baking soda, Starches, Sugars, Salts, Powdered milk, Freeze-dried fruit, Popcorn kernels, Crackers, Nori, Instant coffee, Bouillon cubes, Assorted breads, English muffins, Assorted coffees, Dried stuffing mixes, Cake mix, biscuit or pancake mix, Cold and hot cereals, Cookies and crackers, Dry beans and grains, Dry noodle mixes for the skillet, Flour, sugar, Herbal and regular teas, Macaroni and other pasta, Pizza shells, Powdered drink mixes, White and brown rice, wild rice, Boxed pasta, Tomato paste, Pasta sauce, Canned fish, Canned vegetables, Canned fruit in water, Applesauce, Boxed macaroni and cheese, Chickpeas, Black beans, Chicken broth, Jerky, Granola bars, Bread, Risotto, Eggs, Cheese, Hummus, Shelf-stable silken tofu, Peanut or nut butter, Shelf-stable milk, Meat to freeze"

# %%
dry_goods_df = create_multicolumn_dataframe(a=a)
dry_goods_df = create_single_column_dataframe(a=a)
dry_goods_df

path = './product database/Groceries/dry_goods_database.csv'
dry_goods_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
# Out:
#                         Item
# 0                      Pasta
# 1                       Rice
# 2                    Gnocchi
# 3              Ramen noodles
# 4                     Quinoa
# ..                       ...
# 65                    Hummus
# 66  Shelf-stable silken tofu
# 67      Peanut or nut butter
# 68         Shelf-stable milk
# 69            Meat to freeze
#
# [70 rows x 1 columns]

# %% [markdown]
# ### Condiments

# %%
a = "Ketchup, Mustard, Mayonnaise, BBQ Sauce, Hot Sauce, Soy Sauce, Worcestershire Sauce, Sriracha, Salsa, Tartar Sauce, Horseradish Sauce, Fish Sauce, Teriyaki Sauce, Ranch Dressing, Caesar Dressing, Thousand Island Dressing, Italian Dressing, Blue Cheese Dressing, Balsamic Vinaigrette, Honey Mustard, Relish, Chutney, Hoisin Sauce, Oyster Sauce, Buffalo Sauce, Alfredo Sauce, Pesto Sauce, Peanut Sauce, Tzatziki, Hummus, Guacamole, Aioli, Chimichurri, Gravy, Hollandaise Sauce, Bearnaise Sauce, Gochujang, Harissa, Marmite, Vegemite, Maple Syrup, Chocolate Syrup, Caramel Sauce, Whipped Cream, Apple Sauce, Cranberry Sauce, Mint Sauce, Plum Sauce, Duck Sauce, Sweet and Sour Sauce, Creme Fraiche, Sour Cream, Greek Yogurt, Raita, Sambal Oelek, Miso Paste, Tahini, Tamarind Paste, Cocktail Sauce, Remoulade, Curry Ketchup, Curry Paste, Pico de Gallo, Kimchi, Pickles, Giardiniera, Capers, Olive Tapenade, Jalapeno Jelly, Red Pepper Jelly, Nutella, Peanut Butter, Almond Butter, Cashew Butter, Marshmallow Fluff, Nutritional Yeast, Za'atar, Old Bay Seasoning, Creole Seasoning, Taco Seasoning, Fajita Seasoning, Herbes de Provence, Italian Seasoning, Garam Masala, Chinese Five Spice, Cajun Seasoning, Chili Powder, Cumin, Turmeric, Paprika, Saffron, Cardamom, Cinnamon, Nutmeg, Cloves, Allspice, Star Anise, Fenugreek, Mustard Seeds, Poppy Seeds, Sesame Seeds, Flax Seeds, Sunflower Seeds, Pumpkin Seeds, Black Pepper, White Pepper, Red Pepper Flakes, Cayenne Pepper, Chipotle Powder, Ancho Chile Powder, Garlic Powder, Onion Powder, Sumac, Dill Weed, Basil, Oregano, Thyme, Rosemary, Sage, Bay Leaves, Cilantro, Parsley, Chives, Tarragon, Lemongrass, Curry Leaves, Kaffir Lime Leaves, Seaweed, Wasabi, Pickled Ginger, Dijon Mustard, Stone Ground Mustard, Honey, Agave Syrup, Molasses, Brown Sugar, Powdered Sugar, Demerara Sugar, Coconut Sugar, Stevia, Aspartame, Saccharin, Sucralose, Apple Cider Vinegar, White Vinegar, Red Wine Vinegar, Balsamic Vinegar, Rice Vinegar, Malt Vinegar, Sherry Vinegar, Tamarind Sauce, Pomegranate Molasses, Black Bean Sauce, Plum Sauce, Dashi, Ponzu Sauce, Mirin, Gochugaru, Gochujang, Black Garlic, Fish Roe, Anchovy Paste, Caviar, Sambal, Red Curry Paste, Green Curry Paste, Yellow Curry Paste, Kimchi Paste, Tahini Sauce, Harissa Paste, Guacamole Dip, Guava Jelly, Blackberry Jam, Raspberry Jam, Strawberry Jam, Orange Marmalade, Grape Jelly, Fig Preserves, Date Syrup, Date Paste, Black Olive Tapenade, Green Olive Tapenade, Romesco Sauce, Cilantro Pesto, Sun-Dried Tomato Pesto, Clotted Cream, Quince Paste, Mole Sauce, Peri-Peri Sauce, Piri-Piri Sauce, Enchilada Sauce, A1 Steak Sauce, Brown Sauce, Pickled Peppers, Sweet Pickle Relish, Sushi Ginger"

# %%
condiments_df = create_multicolumn_dataframe(a=a)
condiments_df = create_single_column_dataframe(a=a)
condiments_df

path = './product database/Groceries/condiments_database.csv'
condiments_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
# Out:
#                     Item
# 0                Ketchup
# 1                Mustard
# 2             Mayonnaise
# 3              BBQ Sauce
# 4              Hot Sauce
# ..                   ...
# 191       A1 Steak Sauce
# 192          Brown Sauce
# 193      Pickled Peppers
# 194  Sweet Pickle Relish
# 195         Sushi Ginger
#
# [196 rows x 1 columns]

# %% [markdown]
# ### Snacks

# %%
a = "Potato Chips, Tortilla Chips, Popcorn, Pretzels, Cheese Puffs, Doritos, Cheetos, Fritos, Lay's Chips, Ruffles, Pringles, Kettle Chips, Sun Chips, Funyuns, Bugles, Takis, Plantain Chips, Pork Rinds, Veggie Chips, Trail Mix, Rice Cakes, Cracker Jack, Goldfish Crackers, Wheat Thins, Ritz Crackers, Triscuits, Cheez-Its, Oreo Cookies, Chocolate Chip Cookies, Snickerdoodles, Peanut Butter Cookies, Biscotti, Shortbread Cookies, Fig Newtons, Milanos, Nutter Butters, Animal Crackers, Ginger Snaps, Oreos, Famous Amos Cookies, Twinkies, Ding Dongs, Ho Hos, Little Debbie Snacks, Zebra Cakes, Swiss Rolls, Nutty Bars, Gummy Bears, Sour Patch Kids, Skittles, M&M's, Reese's Pieces, Kit Kat, Twix, Snickers, Milky Way, 3 Musketeers, Starburst, Swedish Fish, Jolly Ranchers, Tootsie Rolls, Dots, Airheads, Nerds, Sour Straws, Licorice, Gummi Worms, Beef Jerky, Slim Jims, Combos, Fruit Leather, Fruit Snacks, Granola Bars, Rice Krispies Treats, Nut Mixes, Fruit and Nut Bars, Chocolate Covered Pretzels, Fruit Chips, Pita Chips, Bagel Chips, Fruit Cups, Greek Yogurt Parfait, String Cheese, Baby Carrots and Hummus, Celery Sticks with Peanut Butter, Apple Slices with Caramel Dip, Mixed Nuts, Cashews, Almonds, Pistachios, Peanuts, Macadamia Nuts, Walnuts, Trail Mix, Dried Fruit, Fig Bars, Pop Tarts, Fruit Pies, Rice Krispies Treats, Jello Cups, Pudding Cups, Fruit Popsicles, Ice Cream Bars, Yogurt Tubes, Cheese and Crackers, Mini Quiches, Taquitos, Mozzarella Sticks, Jalapeno Poppers, Potato Skins, Quesadillas, Chicken Wings, Spring Rolls, Sushi Rolls, Shrimp Cocktail, Stuffed Mushrooms, Bruschetta, Caprese Skewers, Deviled Eggs, Mini Meatballs, Sliders, Nachos, Guacamole and Salsa, Spinach Dip, Artichoke Dip, Crab Rangoon, Chicken Tenders, Mini Corn Dogs, French Fries, Onion Rings, Buffalo Cauliflower Bites, Tater Tots, Fried Pickles, Fried Green Tomatoes, Fried Cheese Curds, Poutine, Churros, Funnel Cake, Deep Fried Oreos, Mini Donuts, Soft Pretzels, Caramel Popcorn, Peanut Brittle, Rice Krispies Treats, Chocolate-Covered Strawberries, Candied Apples, Snow Cones, Cotton Candy, Fun-Dip, Fruit Roll-Ups, Pocky, Gummy Worms, Licorice Twists, Laffy Taffy, Now and Later, Warheads, Jelly Belly Jelly Beans, Mike and Ike, Lemonheads, Atomic Fireballs, Jujubes, Bazooka Gum, Chick-o-Sticks, Mary Jane, Charleston Chew, Bit-O-Honey, Heath Bar, 100 Grand Bar, Almond Joy, Mounds, Baby Ruth, PayDay, Butterfinger, Crunch Bar, Hershey's Kisses, Milky Way Midnight, Hershey's Cookies 'n' Creme, Reese's Peanut Butter Cups, 5th Avenue Bar, Zero Bar, York Peppermint Pattie, Mr. Goodbar, Cadbury Creme Egg, Toblerone, Ferrero Rocher, Lindt Truffles, Godiva Chocolate, Ghirardelli Chocolate, Hershey's Chocolate Bars, Dove Chocolate, Ritter Sport, Kinder Chocolate, Milka Chocolate, Cadbury Dairy Milk, Aero Chocolate, Terry's Chocolate Orange, Galaxy Chocolate, Lindt Chocolate Bars, Green and Black's Chocolate, Toblerone Chocolate"

# %%
snacks_df = create_multicolumn_dataframe(a=a)
snacks_df = create_single_column_dataframe(a=a)
snacks_df

path = './product database/Groceries/snacks_database.csv'
snacks_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
# Out:
#                             Item
# 0                   Potato Chips
# 1                 Tortilla Chips
# 2                        Popcorn
# 3                       Pretzels
# 4                   Cheese Puffs
# ..                           ...
# 195     Terry's Chocolate Orange
# 196             Galaxy Chocolate
# 197         Lindt Chocolate Bars
# 198  Green and Black's Chocolate
# 199          Toblerone Chocolate
#
# [200 rows x 1 columns]

# %% [markdown]
# ### Beverages(no Alcohol)

# %%
beverages_df = create_multicolumn_dataframe(a=a)
beverages_df = create_single_column_dataframe(a=a)
beverages_df

path = './product database/Groceries/beverages_database.csv'
beverages_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Clothing

# %% [markdown]
# ### shoes

# %%
shoes_df = create_multicolumn_dataframe(a=a)
shoes_df = create_single_column_dataframe(a=a)
shoes_df

path = './product database/Clothing/shoes_database.csv'
shoes_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### jewelry

# %%
jewelry_df = create_multicolumn_dataframe(a=a)
jewelry_df = create_single_column_dataframe(a=a)
jewelry_df

path = './product database/Clothing/jewelry_database.csv'
jewelry_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### handbags

# %%
handbags_df = create_multicolumn_dataframe(a=a)
handbags_df = create_single_column_dataframe(a=a)
handbags_df

path = './product database/Clothing/handbags_database.csv'
handbags_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### wallets

# %%
wallets_df = create_multicolumn_dataframe(a=a)
wallets_df = create_single_column_dataframe(a=a)
wallets_df

path = './product database/Clothing/wallets_database.csv'
wallets_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### belts

# %%
belts_df = create_multicolumn_dataframe(a=a)
belts_df = create_single_column_dataframe(a=a)
belts_df

path = './product database/Clothing/belts_database.csv'
belts_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### hats

# %%
hats_df = create_multicolumn_dataframe(a=a)
hats_df = create_single_column_dataframe(a=a)
hats_df

path = './product database/Clothing/hats_database.csv'
hats_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### sunglasses

# %%
sunglasses_df = create_multicolumn_dataframe(a=a)
sunglasses_df = create_single_column_dataframe(a=a)
sunglasses_df

path = './product database/Clothing/sunglasses_database.csv'
sunglasses_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Electronics

# %% [markdown]
# ### Computers

# %%
computers_df = create_multicolumn_dataframe(a=a)
computers_df = create_single_column_dataframe(a=a)
computers_df

path = './product database/Electronics/computers_database.csv'
computers_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### mobile phones

# %%
phones_df = create_multicolumn_dataframe(a=a)
phones_df = create_single_column_dataframe(a=a)
phones_df

path = './product database/Electronics/phones_database.csv'
phones_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### tablets

# %%
tablets_df = create_multicolumn_dataframe(a=a)
tablets_df = create_single_column_dataframe(a=a)
tablets_df

path = './product database/Electronics/tablets_database.csv'
tablets_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### TVs

# %%
tvs_df = create_multicolumn_dataframe(a=a)
tvs_df = create_single_column_dataframe(a=a)
tvs_df

path = './product database/Electronics/tvs_database.csv'
tvs_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### audio equipment

# %%
audio_equipment_df = create_multicolumn_dataframe(a=a)
audio_equipment_df = create_single_column_dataframe(a=a)
audio_equipment_df

path = './product database/Electronics/audio_equipment_database.csv'
audio_equipment_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### cameras

# %%
cameras_df = create_multicolumn_dataframe(a=a)
cameras_df = create_single_column_dataframe(a=a)
cameras_df

path = './product database/Electronics/cameras_database.csv'
cameras_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### electronic accessories

# %%
electronic_accessories_df = create_multicolumn_dataframe(a=a)
electronic_accessories_df = create_single_column_dataframe(a=a)
electronic_accessories_df

path = './product database/Electronics/electronic_accessories_database.csv'
electronic_accessories_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Home & Garden

# %% [markdown]
# ### Furniture

# %%
furniture_df = create_multicolumn_dataframe(a=a)
furniture_df = create_single_column_dataframe(a=a)
furniture_df

path = './product database/Home Garden/furniture_database.csv'
furniture_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### home decor

# %%
home_decor_df = create_multicolumn_dataframe(a=a)
home_decor_df = create_single_column_dataframe(a=a)
home_decor_df

path = './product database/Home Garden/home_decor_database.csv'
home_decor_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### kitchenware

# %%
kitchenware_df = create_multicolumn_dataframe(a=a)
kitchenware_df = create_single_column_dataframe(a=a)
kitchenware_df

path = './product database/Home Garden/kitchenware_database.csv'
kitchenware_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### bedding

# %%
bedding_df = create_multicolumn_dataframe(a=a)
bedding_df = create_single_column_dataframe(a=a)
bedding_df

path = './product database/Home Garden/bedding_database.csv'
bedding_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### garden tools

# %%
garden_tools_df = create_multicolumn_dataframe(a=a)
garden_tools_df = create_single_column_dataframe(a=a)
garden_tools_df

path = './product database/Home Garden/garden_tools_database.csv'
garden_tools_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### plants

# %%
plants_df = create_multicolumn_dataframe(a=a)
plants_df = create_single_column_dataframe(a=a)
plants_df

path = './product database/Home Garden/plants_database.csv'
plants_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### outdoor equipment

# %%
outdoor_equipment_df = create_multicolumn_dataframe(a=a)
outdoor_equipment_df = create_single_column_dataframe(a=a)
outdoor_equipment_df

path = './product database/Home Garden/outdoor_equipment_database.csv'
outdoor_equipment_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Health & Beauty

# %% [markdown]
# ### Pharmacy items

# %%
pharmacy_df = create_multicolumn_dataframe(a=a)
pharmacy_df = create_single_column_dataframe(a=a)
pharmacy_df

path = './product database/Health Beauty/pharmacy_database.csv'
pharmacy_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### cosmetics

# %%
cosmetics_df = create_multicolumn_dataframe(a=a)
cosmetics_df = create_single_column_dataframe(a=a)
cosmetics_df

path = './product database/Health Beauty/cosmetics_database.csv'
cosmetics_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### skincare products

# %%
skincare_df = create_multicolumn_dataframe(a=a)
skincare_df = create_single_column_dataframe(a=a)
skincare_df

path = './product database/Health Beauty/skincare_database.csv'
skincare_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### haircare products

# %%
haircare_df = create_multicolumn_dataframe(a=a)
haircare_df = create_single_column_dataframe(a=a)
haircare_df

path = './product database/Health Beauty/haircare_database.csv'
haircare_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Restaurants & Food Services

# %% [markdown]
# ### fast food

# %%
fastfood_df = create_multicolumn_dataframe(a=a)
fastfood_df = create_single_column_dataframe(a=a)
fastfood_df

path = './product database/Food Services/fastfood_database.csv'
fastfood_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### casual dining

# %%
casual_dining_df = create_multicolumn_dataframe(a=a)
casual_dining_df = create_single_column_dataframe(a=a)
casual_dining_df

path = './product database/Food Services/casual_dining_database.csv'
casual_dining_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### fine dining

# %%
fine_dining_df = create_multicolumn_dataframe(a=a)
fine_dining_df = create_single_column_dataframe(a=a)
fine_dining_df

path = './product database/Food Services/fine_dining_database.csv'
fine_dining_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### cafes

# %%
cafes_df = create_multicolumn_dataframe(a=a)
cafes_df = create_single_column_dataframe(a=a)
cafes_df

path = './product database/Food Services/cafes_database.csv'
cafes_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### bakeries

# %%
bakeriess_df = create_multicolumn_dataframe(a=a)
bakeriess_df = create_single_column_dataframe(a=a)
bakeriess_df

path = './product database/Food Services/bakeries_database.csv'
bakeriess_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Automotive

# %% [markdown]
# ### Gasoline

# %%
gasoline_df = create_multicolumn_dataframe(a=a)
gasoline_df = create_single_column_dataframe(a=a)
gasoline_df

path = './product database/Automotive/gasoline_database.csv'
gasoline_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### car parts

# %%
car_parts_df = create_multicolumn_dataframe(a=a)
car_parts_df = create_single_column_dataframe(a=a)
car_parts_df

path = './product database/Automotive/car_parts_database.csv'
car_parts_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### car accessories

# %%
car_accessories_df = create_multicolumn_dataframe(a=a)
car_accessories_df = create_single_column_dataframe(a=a)
car_accessories_df

path = './product database/Automotive/car_accessories_database.csv'
car_accessories_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Entertainment & Leisure

# %% [markdown]
# ### tickets

# %%
tickets_df = create_multicolumn_dataframe(a=a)
tickets_df = create_single_column_dataframe(a=a)
tickets_df

path = './product database/Entertainment Leisure/tickets_database.csv'
tickets_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### books

# %%
books_df = create_multicolumn_dataframe(a=a)
books_df = create_single_column_dataframe(a=a)
books_df

path = './product database/Entertainment Leisure/books_database.csv'
books_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### magazines

# %%
magazines_df = create_multicolumn_dataframe(a=a)
magazines_df = create_single_column_dataframe(a=a)
magazines_df

path = './product database/Entertainment Leisure/magazines_database.csv'
magazines_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### sports equipment

# %%
sports_equipment_df = create_multicolumn_dataframe(a=a)
sports_equipment_df = create_single_column_dataframe(a=a)
sports_equipment_df

path = './product database/Entertainment Leisure/sports_equipment_database.csv'
sports_equipment_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### hobby supplies

# %%
hobby_supplies_df = create_multicolumn_dataframe(a=a)
hobby_supplies_df = create_single_column_dataframe(a=a)
hobby_supplies_df

path = './product database/Entertainment Leisure/hobby_supplies_database.csv'
hobby_supplies_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### toys

# %%
toys_df = create_multicolumn_dataframe(a=a)
toys_df = create_single_column_dataframe(a=a)
toys_df

path = './product database/Entertainment Leisure/toys_database.csv'
toys_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### games

# %%
games_df = create_multicolumn_dataframe(a=a)
games_df = create_single_column_dataframe(a=a)
games_df

path = './product database/Entertainment Leisure/games_database.csv'
games_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Travel & Accommodation

# %% [markdown]
# ### Hotel bookings

# %%
hotel_bookings_df = create_multicolumn_dataframe(a=a)
hotel_bookings_df = create_single_column_dataframe(a=a)
hotel_bookings_df

path = './product database/Travel Accommodation/hotel_bookings_database.csv'
hotel_bookings_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### flight tickets

# %%
flight_tickets_df = create_multicolumn_dataframe(a=a)
flight_tickets_df = create_single_column_dataframe(a=a)
flight_tickets_df

path = './product database/Travel Accommodation/flight_tickets_database.csv'
flight_tickets_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### car rentals

# %%
car_rentals_df = create_multicolumn_dataframe(a=a)
car_rentals_df = create_single_column_dataframe(a=a)
car_rentals_df

path = './product database/Travel Accommodation/car_rentals_database.csv'
car_rentals_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Education & Office Supplies

# %% [markdown]
# ### School supplies

# %%
school_supplies_df = create_multicolumn_dataframe(a=a)
school_supplies_df = create_single_column_dataframe(a=a)
school_supplies_df

path = './product database/Education Office Supplies/school_supplies_database.csv'
school_supplies_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### office stationery

# %%
office_stationery_df = create_multicolumn_dataframe(a=a)
office_stationery_df = create_single_column_dataframe(a=a)
office_stationery_df

path = './product database/Education Office Supplies/office_stationery_database.csv'
office_stationery_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Pets

# %% [markdown]
# ### Pet food

# %%
pet_food_df = create_multicolumn_dataframe(a=a)
pet_food_df = create_single_column_dataframe(a=a)
pet_food_df

path = './product database/Pets/pet_food_database.csv'
pet_food_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### pet care products

# %%
pet_care_df = create_multicolumn_dataframe(a=a)
pet_care_df = create_single_column_dataframe(a=a)
pet_care_df

path = './product database/Pets/pet_care_database.csv'
pet_care_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### pet toys

# %%
pet_toys_df = create_multicolumn_dataframe(a=a)
pet_toys_df = create_single_column_dataframe(a=a)
pet_toys_df

path = './product database/Pets/pet_toys_database.csv'
pet_toys_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Services

# %% [markdown]
# ### veterinary services

# %%
veterinary_df = create_multicolumn_dataframe(a=a)
veterinary_df = create_single_column_dataframe(a=a)
veterinary_df

path = './product database/services/veterinary_database.csv'
veterinary_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### car wash services

# %%
car_wash_df = create_multicolumn_dataframe(a=a)
car_wash_df = create_single_column_dataframe(a=a)
car_wash_df

path = './product database/services/car_wash_database.csv'
car_wash_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### Haircuts

# %%
haircuts_df = create_multicolumn_dataframe(a=a)
haircuts_df = create_single_column_dataframe(a=a)
haircuts_df

path = './product database/services/haircuts_database.csv'
haircuts_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### salon services

# %%
salon_df = create_multicolumn_dataframe(a=a)
salon_df = create_single_column_dataframe(a=a)
salon_df

path = './product database/services/salon_database.csv'
salon_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### laundry

# %%
laundry_df = create_multicolumn_dataframe(a=a)
laundry_df = create_single_column_dataframe(a=a)
laundry_df

path = './product database/services/laundry_database.csv'
laundry_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### dry cleaning

# %%
dry_cleaning_df = create_multicolumn_dataframe(a=a)
dry_cleaning_df = create_single_column_dataframe(a=a)
dry_cleaning_df

path = './product database/services/dry_cleaning_database.csv'
dry_cleaning_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### repair services

# %%
repair_df = create_multicolumn_dataframe(a=a)
repair_df = create_single_column_dataframe(a=a)
repair_df

path = './product database/services/repair_database.csv'
repair_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### legal services

# %%
legal_df = create_multicolumn_dataframe(a=a)
legal_df = create_single_column_dataframe(a=a)
legal_df

path = './product database/services/legal_database.csv'
legal_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### financial services

# %%
financial_df = create_multicolumn_dataframe(a=a)
financial_df = create_single_column_dataframe(a=a)
financial_df

path = './product database/services/financial_database.csv'
financial_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### car maintenance services

# %%
car_maintenance_df = create_multicolumn_dataframe(a=a)
car_maintenance_df = create_single_column_dataframe(a=a)
car_maintenance_df

path = './product database/services/car_maintenance_database.csv'
car_maintenance_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# # Alcohol & Tobacco

# %% [markdown]
# ### Beers

# %%
beers_df = create_multicolumn_dataframe(a=a)
beers_df = create_single_column_dataframe(a=a)
beers_df

path = './product database/Alcohol Tobacco/beers_database.csv'
beers_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### wines

# %%
wines_df = create_multicolumn_dataframe(a=a)
wines_df = create_single_column_dataframe(a=a)
wines_df

path = './product database/Alcohol Tobacco/wines_database.csv'
wines_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### spirits

# %%
spirits_df = create_multicolumn_dataframe(a=a)
spirits_df = create_single_column_dataframe(a=a)
spirits_df

path = './product database/Alcohol Tobacco/spirits_database.csv'
spirits_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered

# %% [markdown]
# ### cigarettes

# %%
cigarettes_df = create_multicolumn_dataframe(a=a)
cigarettes_df = create_single_column_dataframe(a=a)
cigarettes_df

path = './product database/Alcohol Tobacco/cigarettes_database.csv'
cigarettes_df.to_csv(path, encoding='utf-8', index=False)
df = pd.read_csv(path)
df

df_filtered = df[~df.apply(lambda row: row.astype(str).str.contains(r'\?').any(), axis=1)]

df_filtered.to_csv(path, encoding='utf-8', index=False)
df_filtered
